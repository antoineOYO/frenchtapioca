# %%
from opentapioca.wikidatagraph import WikidataGraph
from opentapioca.languagemodel import BOWLanguageModel
from opentapioca.tagger import Tagger
from opentapioca.classifier import SimpleTagClassifier
import settings
import numpy as np
import bz2
import json

# %% [markdown]
# ### classe ```WikidataObject```

# %%
import requests
import json
import geopy

class WikidataObject:

    def __init__(self, uri=None, label=None, jsondata=None, coordinates=None):

        if uri is not None:
            if isinstance(uri, (int, float)):
                self.uri = 'Q' + str(int(uri))
            elif isinstance(uri, str):
                if uri[0] == 'Q':
                    self.uri = uri
                else:
                    raise ValueError("URI should start with 'Q' if it's a string.")
        else:
            self.uri = None

        self.label = label
        self.coordinates = coordinates
        self.json = jsondata

        if self.uri is not None:
            self.link = f'https://www.wikidata.org/wiki/{self.uri}'
        else:
            self.link = None

    def __repr__(self):
        return self.link

    def __iter__(self):
        return self.json.__iter__()

    def request_json(self):
        if self.uri is None:
            raise AttributeError("URI is not set.")

        if self.json:
            return self.json

        try:
            url = f'https://www.wikidata.org/wiki/Special:EntityData/{self.uri}.json'
            response = requests.get(url)
            data = response.json()
            self.json = data
            return data

        except Exception as e:
            print('Error requesting JSON at URL:', url)
            print(e)
            return None

    def get_coordinates(self):
        if isinstance(self.coordinates, (tuple, list)) and len(self.coordinates) == 2:
            return self.coordinates

        if self.json:
            try:
                coordinates_dict = self.json['entities'][list(self.json['entities'].keys())[0]]['claims']['P625'][0]['mainsnak']['datavalue']['value']
                self.coordinates = (coordinates_dict['latitude'], coordinates_dict['longitude'])
                return self.coordinates
            except:
                pass

        else:
            json_data = self.request_json()
            if json_data:
                return self.get_coordinates()

    def distance_to(self, other):
        self.get_coordinates()

        if isinstance(other, (int, str, float)):
            other = WikidataObject(uri=other)
            other.get_coordinates()

        if isinstance(other, WikidataObject):
            other.get_coordinates()
            if not self.coordinates or not other.coordinates:
                return None
            else:
                d = geopy.distance.distance(self.coordinates, other.coordinates).km
                return d

        elif isinstance(other, (tuple, list)) and len(other) == 2:
            return geopy.distance.distance(self.coordinates, other).km

# %%
q1 = 'Q1613150' # canton de Vivonne
q2 = 'Q1727971' # 1  :  Vivonne
q3 = 'Q2314920' # 2  :  gare de Vivonne
paris  = 'Q90' # paris


CHABLIS = WikidataObject(uri = 'Q331232')

wd1 = WikidataObject(uri = 'Q1613150')
wd2 = WikidataObject(uri = 'Q704', coordinates=VILLESFR.loc[254,'truthyV_coords'])
paris = WikidataObject(uri = 'Q90')
versailles = WikidataObject(uri = 'Q621')    

print(wd1.distance_to(versailles))
print(paris.distance_to(VILLESFR.loc[254,'truthyV_coords']))
# Out:
# 299.0405117165616
# 157.75798052056592

# %%
print(wd2.distance_to('Q25278623'))
# Out:
# 12530.782567194068

# %% [markdown]
# ### Get small labels

# %%
# read json.bz2 file and get all json in it:
filepath = 'data/small/small.json.bz2'
french_label = ''

with bz2.open(filepath, 'rt') as bz_file:
    # Iterate through each line in the file
    for line in bz_file:
        # Parse JSON data from each line
        data = json.loads(line)
        
        # Check if the entity has French labels
        if 'labels' in data and 'fr' in data['labels']:
            # Extract and print the French label
            label = data['labels']['fr']['value']
            french_label += label + ' % '

print(french_label)
# Out:
# Berre-l'Étang % Varambon % Saint-Agrève % Châteauvillain % Castelnaudary % Barbonne-Fayel % Lagnieu % Olliergues % Rougemont % Saint-Aignan % Barre-des-Cévennes % Saint-Marcellin % Denain % Aubigny % Carhaix-Plouguer % Alès % Tours % Château-Chinon % Wintzenheim-Kochersberg % Conches-en-Ouche % Pont-de-Vaux % Saint-Valery-en-Caux % Mont-Louis % Montélimar % Brive-la-Gaillarde % Revin % Castres % Chevreuse % Dax % Beaujeu % Montsaugeon % Céret % Conflans-en-Jarnisy % Aigueperse % Aix-en-Provence % Bar-sur-Seine % Clairac % Torigni-sur-Vire % Chârost % Aigremont % Aiguillon % Chênehutte-Trèves-Cunault % La Ferté-Bernard % Aire-sur-l'Adour % Renty % Agen % Noyon % Duras % Ainay-le-Château % Aignay-le-Duc % Arnay-le-Duc % Auvillar % Villé % Aigurande % Saint-Affrique % Cessenon-sur-Orb % Saint-James % La Rochefoucauld % Pontorson % Aigues-Mortes % Rambervillers % Aix % Chinon % Rohan % Rosheim % Lourdes % Pacy-sur-Eure % La Réole % Reims % L'Aigle % Toucy % Brionne % Chantelle % Châtellerault % Valence % Montmerle-sur-Saône % Compiègne % Belfort % Solignac-sur-Loire % Ballon % Saint-Tropez % Guingamp % Marquefave % Chaource % Villefranche-de-Conflent % Sainte-Maure-de-Touraine % Aisey-sur-Seine % Meaux % Bayeux % Argentat % Neufchâtel-en-Bray % Clerval % Agde % Cadalen % Béthune %

# %% [markdown]
# ### BOW etc

# %%
bow = BOWLanguageModel()
if settings.LANGUAGE_MODEL_PATH:
    bow.load(settings.LANGUAGE_MODEL_PATH)
    print(settings.LANGUAGE_MODEL_PATH)

graph = WikidataGraph()
if settings.PAGERANK_PATH:
    graph.load_pagerank(settings.PAGERANK_PATH)
    print(settings.PAGERANK_PATH)
    
tagger = None
classifier = None

if settings.SOLR_COLLECTION:
    tagger = Tagger(settings.SOLR_COLLECTION, bow, graph)
    print(settings.SOLR_COLLECTION)
    classifier = SimpleTagClassifier(tagger)
    if settings.CLASSIFIER_PATH:
        classifier.load(settings.CLASSIFIER_PATH)
        print(settings.CLASSIFIER_PATH)
# Out:
# data/all-french.bow.pkl
# data/wikidata/wikidata-graph.pgrank.npy
# frenchtapioca4
# data/latest_classifier.pkl
# /home/antoine/anaconda3/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 1.3.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/antoine/anaconda3/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearSVC from version 1.3.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/antoine/anaconda3/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 1.3.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
text = 'Villeurbanne, Lyon et Miribel sont 3 agglomérations lyonnaises.'
if not classifier:
    mentions = tagger.tag_and_rank(text)
else:
    mentions = classifier.create_mentions(text)
    classifier.classify_mentions(mentions)


for m in mentions:
    besttag = sorted(m.json()['tags'], key=lambda x: x['score'])[-1]
    print(text[m.start:m.end],
          ' tagged as ',
          besttag['label'],
          besttag['id'],
          ' with log likelihood ', 
          # arrondi à 10-2 :
          np.round(m.json()['log_likelihood'], 3))
# Out:
# Villeurbanne  tagged as  Villeurbanne Q582  with log likelihood  12.833
# Lyon  tagged as  Lyon Q456  with log likelihood  9.863
# Miribel  tagged as  Miribel Q363100  with log likelihood  13.151

# %% [markdown]
# ### Once

# %%
import pandas as pd
VILLESFR = pd.read_json('/home/antoine/Documents/GitHub/ner-spancat-edda/VILLESFR_with_OpenTapiocaDoc.json')
VILLESFR_collec = pd.read_json('/home/antoine/Documents/GitHub/ner-spancat-edda/VILLESFR_collec.json')

# %%
VILLESFR.at[254, 'truthyV'] = 'Q331232'

# %%
VILLESFR = VILLESFR[['key', 'head', 'head_root', 'SAINT', 'truthyV', 'truthyV_coords',
       'truthyV_JSON', 'truthyV_spellings', 'truthyV_population',
       'fullcontent', 'OpenTapiocaDoc']]

# %%
VILLESFR.to_json('/home/antoine/Documents/GitHub/toponym-disambiguation/data/VILLESFR_010324.json')

# %% [markdown]
# # Testing

# %%
import pandas as pd
VILLESFR = pd.read_json('/home/antoine/Documents/GitHub/toponym-disambiguation/data/VILLESFR_010324.json')

# %%
for idx,row in VILLESFR.iterrows():
    print(str(idx) + "  ######################################")
    document = row['OpenTapiocaDoc']
    print(document)
    if not classifier:
        mentions = tagger.tag_and_rank(document)
    else:
        mentions = classifier.create_mentions(document)
        classifier.classify_mentions(mentions)

    firstmention = mentions[0]
    firstmention_text = document[firstmention.start:firstmention.end]
    firstmention_tags = sorted(firstmention.json()['tags'],
                               key=lambda x: x['score'],
                               reverse=True)
    
    doc_head = document.split('%')[0]
    
    if firstmention_text in doc_head:

        VILLESFR.loc[idx,'TapiocaPredictions'] = firstmention
        BestPrediction = WikidataObject(uri = firstmention_tags[0]['id'],
                                        label = firstmention_tags[0]['label'])
        print(BestPrediction)
        #VILLESFR.loc[idx,'TapiocaBestPrediction'] = BestPrediction
        distance_to_truth = BestPrediction.distance_to(row['truthyV'])
        VILLESFR.loc[idx,'TapiocaDist2Truth'] = distance_to_truth
        
        print('Head ' , firstmention_text, ' tagged successfully : ', )
        print('Distance to truth : ', distance_to_truth)
        for rank,tag in enumerate(firstmention_tags):
            to_print = ''

            if tag['id'] == row['truthyV']:
                to_print += '____________'
            
            print(to_print, rank, ' : ',  tag['label'], tag['id'], tag['score'])
    
    print()
    print()
            
                    

    if False :
        for m in mentions:
            besttag = sorted(m.json()['tags'], key=lambda x: x['score'])[-1]
            print(text[m.start:m.end],
                ' tagged as ',
                besttag['label'],
                besttag['id'],
                ' with log likelihood ', 
                # arrondi à 10-2 :
                np.round(m.json()['log_likelihood'], 3)
            )
# Out:
# 0  ######################################
# AFRIQUE % France % Gascogne % Montauban
# https://www.wikidata.org/wiki/Q15
# Head  AFRIQUE  tagged successfully :
# Distance to truth :  2566.790159142138
#  0  :  Afrique Q15 1.1875239766646337
#  1  :  Afrique de l'Est Q27407 -0.19199924028322224
#  2  :  plaque africaine Q203548 -0.8301643724007213
#  3  :  L'Afrique Q112871204 -1.5541575604908873
#
#
# 1  ######################################
# AGDE % France % Languedoc % Paris % d'Agadez
# https://www.wikidata.org/wiki/Q191396
# Head  AGDE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Agde Q191396 -0.0009736785317753238
#  1  :  canton d'Agde Q187517 -0.2181590004845937
#  2  :  gare d'Agde Q2028453 -0.6182421433834153
#
#
# 2  ######################################
# AGEN % France % l'Agénois % la Guienne % la Garonne
# https://www.wikidata.org/wiki/Q6625
# Head  AGEN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Agen Q6625 0.7336394672830173
#  1  :  arrondissement d'Agen Q700351 -0.22935372707161916
#  2  :  gare d'Agen Q2244575 -0.7405543705294092
#  3  :  arrêt Agen Q56859294 -0.8055209775654759
#  4  :  Agen Q16275638 -1.3354343803211102
#  5  :  Agen Q16275641 -1.3356760605662332
#  6  :  Agen (bukid) Q23678115 -1.3356760605662332
#  7  :  Agen Q16275639 -1.3366427815467254
#
#
# 3  ######################################
# AGRERE % France % Monts % le haut-Vivarez
#
#
# 4  ######################################
# AIGLE % France % Rouen % d'Evreux % la haute Normandie
# https://www.wikidata.org/wiki/Q500588
# Head  AIGLE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  L'Aigle Q500588 -0.3277155120861627
#  1  :  canton de L'Aigle-Est Q1726024 -0.562382352716797
#  2  :  District d'Aigle Q647923 -0.6086715616443378
#  3  :  canton de l'Aigle Q17622682 -0.6166628838242758
#  4  :  Aigle Q43195 -0.6504440543581216
#  5  :  L'Aigle Q3096721 -0.8893689161987761
#  6  :  L'Aigle Q3201627 -0.9911849542664493
#  7  :  station météorologique de L'Aigle Q117882688 -0.9959029312448142
#  8  :  gare d'Aigle Q5845601 -1.1461634614577894
#  9  :  Edzell Q1011820 -1.243927604695902
#
#
# 5  ######################################
# AIGNAI-LE-DUC % France % Bourgogne % Dijon
# https://www.wikidata.org/wiki/Q183
# Head  DUC  tagged successfully :
# Distance to truth :  532.6470983228072
#  0  :  Allemagne Q183 1.2393730488385999
#  1  :  峪山镇 Q11052128 -1.2241207242794685
#  2  :  Đức Tôn Q95176156 -1.3335317385212833
#  3  :  aérodrome de Halliburton Field Q7966003 -1.4392722835927634
#  4  :  Quy Đức Q10810167 -1.451540528107758
#  5  :  Đức La Q10842365 -1.4517756980424656
#  6  :  Đức Sơn Q10842424 -1.4520108679771735
#  7  :  Dục Tú Q10757710 -1.4522460379118811
#  8  :  Duć Q27558699 -1.4545487967528299
#
#
# 6  ######################################
# SAINT AIGNAN (SAINT) % France % le Berry % le Cher
# https://www.wikidata.org/wiki/Q1055925
# Head  SAINT AIGNAN  tagged successfully :
# Distance to truth :  244.88973887236247
#  0  :  Mont-Saint-Aignan Q1055925 0.04025909463740018
# ____________ 1  :  Saint-Aignan Q832394 -0.17857998782573214
#  2  :  Saint-Aignan Q952806 -0.20041629068881806
#  3  :  Saint-Aignan Q1427775 -0.25418418555289324
#  4  :  Saint-Aignan Q688478 -0.28899683719146374
#  5  :  Saint-Aignan Q653687 -0.3151950993048038
#  6  :  Saint-Aignan Q127505 -0.3181119345401442
#  7  :  Saint-Aignan-de-Couptrain Q1100124 -0.3476745723272345
#  8  :  canton de Saint-Aignan Q1265718 -0.35225107130762445
#  9  :  Avesnes-en-Val Q1112707 -0.38925742328455504
#
#
# 7  ######################################
# AIGREMONT-LE-DUC % France % Bourgogne % Dijon
# https://www.wikidata.org/wiki/Q1376037
# Head  AIGREMONT  tagged successfully :
# Distance to truth :  290.66731982151333
#  0  :  Aigremont Q1376037 -0.3319727917180252
# ____________ 1  :  Aigremont Q1102347 -0.3810769769038085
#  2  :  Aigremont Q288153 -0.479447285873566
#  3  :  Aigremont Q256129 -0.5313601159914539
#  4  :  Chézelles Q61744156 -0.6698545156029203
#  5  :  Aigremont Q109016658 -1.1919016726447793
#  6  :  Aigremont Q99455281 -1.195283470034224
#  7  :  Aigremont Q30650764 -1.1969230436490652
#  8  :  Aigremont Q61022197 -1.1976257180554257
#
#
# 8  ######################################
# AIGUES-MORTES % France % le bas Languedoc
# https://www.wikidata.org/wiki/Q193809
# Head  AIGUES-MORTES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aigues-Mortes Q193809 -0.18832442968092478
#  1  :  canton d'Aigues-Mortes Q1265527 -0.37154008437529873
#  2  :  gare d'Aigues-Mortes Q3095590 -0.7053425068423276
#  3  :  station météorologique d'Aigues-Mortes Q117882184 -0.7378056649780125
#
#
# 9  ######################################
# AIGLE-PERSE % France % la basse Auvergne
# https://www.wikidata.org/wiki/Q500588
# Head  AIGLE  tagged successfully :
# Distance to truth :  361.5459986867577
#  0  :  L'Aigle Q500588 -0.2718734680882886
#  1  :  District d'Aigle Q647923 -0.41933270395637223
#  2  :  Aigle Q43195 -0.46172463966481275
#  3  :  canton de L'Aigle-Est Q1726024 -0.4975605617051837
#  4  :  canton de l'Aigle Q17622682 -0.5501970981104113
#  5  :  L'Aigle Q3096721 -0.8157214620797968
#  6  :  L'Aigle Q3201627 -0.9144493766752668
#  7  :  station météorologique de L'Aigle Q117882688 -0.9189832832594489
#  8  :  gare d'Aigle Q5845601 -0.9368254453547713
#  9  :  Edzell Q1011820 -1.0317084414451796
#
#
# 10  ######################################
# AIGUILLON % France % Guyenne % l'Agenois
# https://www.wikidata.org/wiki/Q7179
# Head  AIGUILLON  tagged successfully :
# Distance to truth :  198.88004415032665
#  0  :  L'Aiguillon Q7179 -0.2504163053437465
# ____________ 1  :  Aiguillon Q404783 -0.2788797745368019
#  2  :  Aiguillon Q404757 -0.30275188899846883
#  3  :  gare d'Aiguillon Q2325241 -0.7067891796782981
#  4  :  Aiguillon Q61833140 -0.7271497545166533
#  5  :  Aiguillon Q110599076 -0.7405965651423772
#  6  :  station météorologique d'Aiguillon Q118246735 -0.7413094085125123
#  7  :  Aiguillon (kagaangan) Q27118715 -1.2477448157371063
#  8  :  D'Aiguillon Q112855049 -1.2512059523369952
#  9  :  Aiguillon Q28162501 -1.2521699288088282
#
#
# 11  ######################################
# AIGURANDE % France % Berry % la Marche
# https://www.wikidata.org/wiki/Q211643
# Head  AIGURANDE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aigurande Q211643 -0.12704082439811515
#  1  :  canton d'Aigurande Q720217 -0.17772645597047187
#  2  :  Aigurande Q109572315 -0.47702032966777197
#  3  :  station météorologique d'Aigurande Q118246612 -0.47795727278963285
#
#
# 12  ######################################
# AIRE % France % la Gascogne % l'Adour
# https://www.wikidata.org/wiki/Q259903
# Head  AIRE  tagged successfully :
# Distance to truth :  796.836179019365
#  0  :  Aire-sur-la-Lys Q259903 -0.14640868832077114
# ____________ 1  :  Aire-sur-l'Adour Q408608 -0.18829588780333062
#  2  :  Aire Q408617 -0.43356337503943043
#  3  :  Aire Q403349 -0.5410232478109166
#  4  :  Aire Q408614 -0.5479664156144115
#  5  :  Aire (rivière d'Angleterre) Q408636 -0.7800363452796245
#  6  :  Insula Aeris Q1232106 -1.3411087490076044
#  7  :  Aïre Q2876414 -1.3765149160147305
#  8  :  Aire Q115498877 -1.390490336676552
#  9  :  Aire Q115498878 -1.3907302773920962
#
#
# 13  ######################################
# AISAY-LE-DUC % France % Bourgogne % Chatillon
# https://www.wikidata.org/wiki/Q183
# Head  DUC  tagged successfully :
# Distance to truth :  534.0955290785178
#  0  :  Allemagne Q183 1.3312103131649033
#  1  :  峪山镇 Q11052128 -1.0847597446175063
#  2  :  Đức Tôn Q95176156 -1.1930895601627407
#  3  :  aérodrome de Halliburton Field Q7966003 -1.2980780950001227
#  4  :  Quy Đức Q10810167 -1.3101117400416267
#  5  :  Đức La Q10842365 -1.3103462253427036
#  6  :  Đức Sơn Q10842424 -1.3105807106437803
#  7  :  Dục Tú Q10757710 -1.310815195944857
#  8  :  Duć Q27558699 -1.3130615299767339
#
#
# 14  ######################################
# AISNAY-LE-CHASTEAU % France % Bourges
#
#
# 15  ######################################
# AIX % France % Provence % d'Arc
# https://www.wikidata.org/wiki/Q47465
# Head  AIX  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aix-en-Provence Q47465 0.09379924992183453
#  1  :  Gondrecourt-Aix Q218315 -0.4159995076631492
#  2  :  Aix Q411433 -0.5259971458776675
#  3  :  Aix Q411485 -0.6144072253167969
#  4  :  Pœuilly Q587478 -0.6515625237892428
#  5  :  Aix-en-Pévèle Q649694 -0.6556297853440387
#  6  :  Aix Q4699383 -1.2710633594341645
#  7  :  Aix Q21851295 -1.2771962776438048
#  8  :  Astana International Exchange Ltd Q93359852 -1.2801454966137829
#  9  :  Aix Q116234286 -1.2837981563928142
#
#
# 16  ######################################
# AIX % France % le Limosin % la Marche
# https://www.wikidata.org/wiki/Q47465
# Head  AIX  tagged successfully :
# Distance to truth :  336.18028345960204
#  0  :  Aix-en-Provence Q47465 0.12872211743413475
#  1  :  Gondrecourt-Aix Q218315 -0.32573309380910254
#  2  :  Aix Q411433 -0.43937415272689007
# ____________ 3  :  Aix Q411485 -0.5272614895678878
#  4  :  Pœuilly Q587478 -0.5652346979443915
#  5  :  Aix-en-Pévèle Q649694 -0.5690840333876442
#  6  :  Aix Q4699383 -1.2683894926404358
#  7  :  Aix Q21851295 -1.2747991868969497
#  8  :  Astana International Exchange Ltd Q93359852 -1.2778857057731055
#  9  :  Aix Q116234286 -1.281682194161867
#
#
# 17  ######################################
# ALAIS % France % Gardon % le bas Languedoc
# https://www.wikidata.org/wiki/Q193183
# Head  ALAIS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Alès Q193183 0.5754494284169804
#  1  :  Alais Q12382620 -1.0749312190982585
#
#
# 18  ######################################
# SAINT ALBAN (S.) % France % Mende % le bas Languedoc
# https://www.wikidata.org/wiki/Q681135
# Head  SAINT ALBAN  tagged successfully :
# Distance to truth :  217.83097634551973
#  0  :  Saint-Alban Q681135 0.08937970089445202
#  1  :  Saint-Alban-Leysse Q818596 0.07587854800276828
#  2  :  Saint-Alban Q1429203 0.04563728564524716
#  3  :  Saint-Alban Q641836 -0.08628219580009588
#  4  :  Saint-Alban Q49365106 -0.49630917116693274
#  5  :  Saint-Alban Q109573311 -0.49933082196978334
#  6  :  Saint-Alban Q109571398 -0.49980157364591105
#  7  :  Saint-Alban Q3461699 -0.5106390301368093
#  8  :  paroisse de Saint-Alban de Cap-des-Rosiers Q106815621 -0.8530350910716695
#  9  :  Saint-Alban Q113068555 -0.8535081696663318
#
#
# 19  ######################################
# ALBI % France % l'Albigeois % le Tarn % le haut Languedoc
# https://www.wikidata.org/wiki/Q132801
# Head  ALBI  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Albi Q132801 0.40790935803239803
#  1  :  arrondissement d'Albi Q700379 -0.1378281071307087
#  2  :  canton d'Albi-Est Q1724075 -0.7444400006751867
#  3  :  Albino Q53489 -0.8275568968480617
#  4  :  Albi Q53749 -0.8757156875238252
#  5  :  Albi Q284698 -1.0882093884905266
#  6  :  Albi Q12077557 -1.1688692299141399
#  7  :  Albi Q30022081 -1.2237902105156793
#  8  :  Albi Q1186879 -1.411180103693233
#  9  :  ALBi Q11189181 -1.421032454908701
#
#
# 20  ######################################
# ALBRET OU LABRIT % France % Gascogne % d'Albret
# https://www.wikidata.org/wiki/Q496720
# Head  ALBRET  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Labrit Q496720 0.3002053456358871
#  1  :  Albret landais Q2831959 -0.3796126673991016
#  2  :  canton de l'Albret Q17623436 -0.4742118841542011
#
#
# 21  ######################################
# ALENCON % France % la Sarte % la basse Normandie % Alençon % Alençon % Bernay % Bernay % Lizieux % Brionne % Domfront % Vimoutiers % France % Alençon % Lizieux % Orbec % Bernay % Fervaques % Tardoüet % Alençon % Seez % Verneuil % Souance % Nogent-le-Rotrou % Escouche % Argentan % Vimoutiers % Verneuil % Argentan % Nonant % Thimarais % Chansegrai % Varennes % Carouges % Rannes % Houlme % Domfront % d'Argentan % la Bonne-ville
# https://www.wikidata.org/wiki/Q181269
# Head  ALENCON  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Alençon Q181269 -0.08529554498053193
#  1  :  arrondissement d'Alençon Q700385 -0.21539119986274058
#  2  :  Alençon Q2390674 -0.9766731628795791
#  3  :  aérodrome d'Alençon - Valframbert Q2875357 -1.1898252816439008
#  4  :  Alençon Q109572628 -1.2022777867391337
#  5  :  station météorologique d'Alençon Q117882682 -1.2042300210636743
#
#
# 22  ######################################
# ALLASSAC % France % Limoges % le Limosin
# https://www.wikidata.org/wiki/Q1016282
# Head  ALLASSAC  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Allassac Q1016282 -0.3873753985741497
#  1  :  gare d'Allassac Q2571621 -0.7417024307581572
#
#
# 23  ######################################
# ANCENIS % France % la Bretagne % la Loire
# https://www.wikidata.org/wiki/Q213515
# Head  ANCENIS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Ancenis Q213515 -0.008928770048973078
#  1  :  arrondissement d'Ancenis Q700414 -0.1914674718979974
#  2  :  canton d'Ancenis-Saint-Géréon Q1724136 -0.3142116499013303
#  3  :  Ancenis Q2564893 -0.7702295204406999
#  4  :  aérodrome d'Ancenis Q2875366 -0.8453654508348332
#
#
# 24  ######################################
# ANCRE, OU ENCRE % France % Picardie
# https://www.wikidata.org/wiki/Q489438
# Head  ANCRE  tagged successfully :
# Distance to truth :  16.522489484035813
#  0  :  Ancre Q489438 -0.12819231984239232
#  1  :  Ancre Q2846003 -0.19756993458017214
#  2  :  Ancre Q2846001 -0.30159267342222407
#  3  :  Ancre (Belgique) Q2846002 -0.7039867882150217
#  4  :  Ancre Q121221983 -1.0382341028837758
#
#
# 25  ######################################
# ANCY-LE-FRANC % France % Armançon % la Champagne % d'Ancy-le-Savreux
# https://www.wikidata.org/wiki/Q1140847
# Head  ANCY-LE-FRANC  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Ancy-le-Franc Q1140847 0.2331903317050945
#  1  :  canton d'Ancy-le-Franc Q1724141 -0.10180347295675851
#
#
# 26  ######################################
# ANDELY % France % Gambon % la Normandie % la Seine % le grand Andely % le petit Andely
#
#
# 27  ######################################
# ANDONVILLE % France % Paris % Estampes
# https://www.wikidata.org/wiki/Q1105321
# Head  ANDONVILLE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Andonville Q1105321 -0.03695393511369938
#
#
# 28  ######################################
# ANDUZE % France % le Gardon % le bas Languedoc
# https://www.wikidata.org/wiki/Q240921
# Head  ANDUZE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Anduze Q240921 0.2453804784014344
#  1  :  canton d'Anduze Q1574684 -0.2821158350417665
#
#
# 29  ######################################
# ANGERS % France % Anjou % la Loire % la Sarte % la Mayenne
# https://www.wikidata.org/wiki/Q38380
# Head  ANGERS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Angers Q38380 0.45863701398294054
#  1  :  arrondissement d'Angers Q700420 -0.339327773617626
#  2  :  château d'Angers Q1048155 -0.5161046132434703
#  3  :  canton d'Angers-Est Q939198 -0.5723204467498033
#  4  :  Angers Q113067510 -1.2081992765419343
#  5  :  Angers Q28528832 -1.2086673755005761
#  6  :  Angers Q28660470 -1.2089014249798968
#  7  :  Angers Q61021756 -1.2098376228971803
#
#
# 30  ######################################
# ANGLURE % France % Champagne % l'Aube
# https://www.wikidata.org/wiki/Q1060088
# Head  ANGLURE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Anglure Q1060088 -0.1113512620727719
#  1  :  canton d'Anglure Q1690828 -0.24610273031709617
#
#
# 31  ######################################
# ANGOULEME % France % laquelle % l'Angoumois % la Charante
# https://www.wikidata.org/wiki/Q134346
# Head  ANGOULEME  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Angoulême Q134346 0.4771333018076047
#  1  :  arrondissement d'Angoulême Q700427 -0.11195238320568013
#  2  :  canton d'Angoulême-Est Q1724152 -0.32966875139855967
#  3  :  diocèse d'Angoulême Q866855 -0.3670351550834875
#  4  :  cathédrale Saint-Pierre d'Angoulême Q1736169 -0.5131800909300614
#  5  :  gare d'Angoulême Q3095646 -0.7543214559497406
#  6  :  Angoulême Q63242217 -1.4402176629010075
#
#
# 32  ######################################
# ANIANE, OU SAINT-BENOIST D'ANIANE % France % Montpellier % le bas-Languedoc % l'Arre
# https://www.wikidata.org/wiki/Q379780
# Head  ANIANE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aniane Q379780 0.268901163011124
#  1  :  Anyang Q324293 0.18622778376233873
#  2  :  canton d'Aniane Q1724154 0.06289685919644694
#
#
# 33  ######################################
# ANNONAY % France % la Deume % le haut Vivarez
# https://www.wikidata.org/wiki/Q238366
# Head  ANNONAY  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Annonay Q238366 0.3676293643969526
#  1  :  canton d'Annonay-Sud Q1724172 0.15910538822501286
#  2  :  station météorologique d'Annonay Q117881689 -0.27154691547739906
#
#
# 34  ######################################
# ANNOT % France % Provence
# https://www.wikidata.org/wiki/Q157724
# Head  ANNOT  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Annot Q157724 0.29614768825432836
#  1  :  canton d'Annot Q1724183 0.11780937462398433
#  2  :  gare d’Annot Q2258503 -0.2825026056973585
#
#
# 36  ######################################
# ANTIBES % France % Nice % la Provence % la Méditerranée
# https://www.wikidata.org/wiki/Q126898
# Head  ANTIBES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Antibes Q126898 0.11240384268691606
#  1  :  Antibes Q800390 -0.40681652119832235
#  2  :  station météorologique d'Antibes Q117881663 -0.8151123890938312
#  3  :  Антибес Q6557856 -1.0702086249781106
#
#
# 37  ######################################
# ANTRAIN % France % Coësnon % la haute Bretagne
# https://www.wikidata.org/wiki/Q648164
# Head  ANTRAIN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Antrain Q648164 0.18207273629170428
#  1  :  canton de Val-Couesnon Q1724189 0.15847277789828906
#  2  :  Antrain Q49344394 -0.15469851086710795
#
#
# 38  ######################################
# ANTRAIN OU ENTRAINS % France % Auxerre % le Nivernois % d'Auxerre
# https://www.wikidata.org/wiki/Q648164
# Head  ANTRAIN  tagged successfully :
# Distance to truth :  370.8997028933001
#  0  :  Antrain Q648164 -0.67826021630097
#  1  :  canton de Val-Couesnon Q1724189 -0.6999881894586276
#  2  :  Antrain Q49344394 -1.005980436469191
#
#
# 40  ######################################
# APREMONT % France % Poitiers % le Poitou
# https://www.wikidata.org/wiki/Q202829
# Head  APREMONT  tagged successfully :
# Distance to truth :  571.0581651971604
#  0  :  Apremont Q202829 -0.44890074972830496
#  1  :  Apremont Q621826 -0.6020793830303699
#  2  :  Apremont Q621815 -0.6245628291320564
#  3  :  Apremont Q990986 -0.6569990331706734
#  4  :  Apremont-la-Forêt Q286407 -0.6755990932063652
# ____________ 5  :  Apremont Q572125 -0.6817875957365442
#  6  :  Apremont Q766337 -0.690572982618243
#  7  :  Apremont-sur-Allier Q621803 -0.7192381641850218
#  8  :  Apremont Q49344421 -1.063322247007397
#
#
# 41  ######################################
# ARAMONT % France % le Languedoc % d'Uzès % le Rhone
#
#
# 42  ######################################
# ARBOIS % Salins % Poligni % Franche-Comté
# https://www.wikidata.org/wiki/Q1724198
# Head  ARBOIS  tagged successfully :
# Distance to truth :  2.8135211062839565
#  0  :  canton d'Arbois Q1724198 -0.1851295974950813
# ____________ 1  :  Arbois Q330888 -0.46735227011241864
#  2  :  Arbois Q2199980 -0.840658096797648
#  3  :  Arbois Q2859682 -1.0028088792539398
#  4  :  Arbois (cépage) Q630166 -1.017174301677212
#  5  :  Arbois Q110598543 -1.0298181096150159
#
#
# 43  ######################################
# ARCIS-SUR-AUBE % France % Champagne % l'Aube
# https://www.wikidata.org/wiki/Q269401
# Head  ARCIS-SUR-AUBE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Arcis-sur-Aube Q269401 0.07463583385279948
#  1  :  canton d'Arcis-sur-Aube Q390178 -0.16305351408007973
#  2  :  arrondissement d'Arcis-sur-Aube Q2863671 -0.5393307918540571
#  3  :  Arcis-sur-Aube Q120757170 -0.7676374457351549
#
#
# 44  ######################################
# ARDES % France % Mercoeur % la basse-Auvergne
# https://www.wikidata.org/wiki/Q179567
# Head  ARDES  tagged successfully :
# Distance to truth :  1612.7228415891943
#  0  :  Argeș Q179567 -0.2612106074397841
#  1  :  Ardes Q872053 -0.478762289404206
#  2  :  Argeș Q214811 -0.4831329103931928
#  3  :  canton d'Ardes Q276388 -0.48423859484692605
#  4  :  Ardesio Q95073 -0.5998715826155154
#  5  :  Ardez Q64338 -0.738123318736241
#  6  :  Ardes Q49344487 -0.7780220395810781
#
#
# 45  ######################################
# ARDRES % France % la basse Picardie
# https://www.wikidata.org/wiki/Q262456
# Head  ARDRES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Ardres Q262456 -0.21250918186044154
#  1  :  canton d'Ardres Q1724213 -0.22071311206931366
#  2  :  Bonningues-lès-Ardres Q989469 -0.291700932144895
#  3  :  Ardre Q640019 -0.44162096649206806
#  4  :  royaume des Ardres Q640010 -0.5188267974649947
#
#
# 46  ######################################
# ARGENCES % France % basse Normandie % la Méance
# https://www.wikidata.org/wiki/Q838585
# Head  ARGENCES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Argences Q838585 -0.43599214235228656
#  1  :  station météorologique d'Argences Q117881842 -0.8899377077943798
#
#
# 47  ######################################
# ARGENTAC % France % le Limousin % la Dordogne
#
#
# 48  ######################################
# ARGENTAN % France % Séez % l'Orne % la basse Normandie
# https://www.wikidata.org/wiki/Q207622
# Head  ARGENTAN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Argentan Q207622 0.19316654232377384
#  1  :  arrondissement d'Argentan Q700472 0.061954376985748905
#  2  :  canton d'Argentan-Est Q1724212 -0.4645366615519527
#  3  :  Argentan Q3095666 -0.8215017373150821
#  4  :  station météorologique d'Argentan Q117882683 -0.8983017849752648
#
#
# 49  ######################################
# ARGENTON % France % Berri % la Creuse
# https://www.wikidata.org/wiki/Q275438
# Head  ARGENTON  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Argenton-sur-Creuse Q275438 -0.013993344185364798
#  1  :  Argenton Q646469 -0.35899428477482886
#  2  :  Argenton Q735143 -0.49384442370727255
#  3  :  Argenton Q4789513 -1.1006465700976695
#  4  :  Argenton Q29020252 -1.1026005986019176
#
#
# 50  ######################################
# ARLES % France % Provence % le Rhone
# https://www.wikidata.org/wiki/Q48292
# Head  ARLES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Arles Q48292 0.35781594873106104
#  1  :  Arles-sur-Tech Q7897 -0.2541714164791733
#  2  :  arrondissement d'Arles Q700484 -0.35278367497523877
#  3  :  canton d'Arles-Est Q579805 -0.4754537067472932
#  4  :  canton d'Arles Q16912418 -0.49395414726533443
#  5  :  Arles Q1897505 -0.6964979659743814
#  6  :  royaume d'Arles Q3271735 -0.7212030562876122
#  7  :  río Arlés Q6114800 -0.8474693736365194
#  8  :  station météorologique d'Arles Q117881827 -0.9591290923723546
#  9  :  Arles Q2569199 -1.2208294796007182
#
#
# 51  ######################################
# ARLES % France % Perpignan % le Roussillon
# https://www.wikidata.org/wiki/Q48292
# Head  ARLES  tagged successfully :
# Distance to truth :  211.57242854300782
#  0  :  Arles Q48292 -0.09920101414400895
# ____________ 1  :  Arles-sur-Tech Q7897 -0.369917525265208
#  2  :  arrondissement d'Arles Q700484 -0.4697191846452753
#  3  :  canton d'Arles-Est Q579805 -0.5938785164959095
#  4  :  canton d'Arles Q16912418 -0.6126466867990739
#  5  :  Arles Q1897505 -0.8166376075070844
#  6  :  royaume d'Arles Q3271735 -0.8269106475067465
#  7  :  río Arlés Q6114800 -0.9556054377631797
#  8  :  station météorologique d'Arles Q117881827 -1.0816489354085215
#  9  :  Arles Q2569199 -1.3324431157800218
#
#
# 53  ######################################
# ARNAY-LE-DUC % France % Bourgogne % Aroux % l'Auxois
# https://www.wikidata.org/wiki/Q14829
# Head  ARNAY-LE-DUC  tagged successfully :
# Distance to truth :  7.463053954168195e-08
#  0  :  canton d'Arnay-le-Duc Q14829 -0.002699128781576965
# ____________ 1  :  Arnay-le-Duc Q16031 -0.041251326241318775
#
#
# 54  ######################################
# ARQUES % France % Normandie % Caux % Arques
# https://www.wikidata.org/wiki/Q851278
# Head  ARQUES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Arques Q851278 0.15278582962206544
#  1  :  Les Arques Q623793 -0.24455302100879606
#  2  :  Arques Q624917 -0.3318252679507715
#  3  :  Arques Q990611 -0.3937363854241127
#  4  :  Arques Q698998 -0.4330258409928674
#  5  :  canton d'Arques Q951709 -0.46362753560471165
#  6  :  Arques-la-Bataille Q1059971 -0.5104046539212282
#  7  :  gare d'Arques Q16303872 -0.9918324154276716
#  8  :  station météorologique d'Arques Q118246415 -1.031139796476859
#  9  :  les Arques Q107078544 -1.2838190345579439
#
#
# 56  ######################################
# AUBAGNE % France % Provence % la Veaune
# https://www.wikidata.org/wiki/Q184047
# Head  AUBAGNE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aubagne Q184047 0.17940429296502547
#  1  :  canton d'Aubagne-Est Q963484 -0.10420162644399311
#  2  :  canton d'Aubagne Q16912417 -0.20651825359270526
#  3  :  Aubagne Q959669 -0.25765548248937575
#  4  :  station météorologique d'Aubagne Q117881828 -0.5989243081200706
#
#
# 57  ######################################
# AUBENAS % France % Languedoc % Ardesche % Cevennes % le bas Vivarais
# https://www.wikidata.org/wiki/Q211121
# Head  AUBENAS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aubenas Q211121 -0.033442077323362907
#  1  :  canton d'Aubenas Q957203 -0.24148562719872635
#  2  :  station météorologique d'Aubenas (SA) Q117881691 -0.6468007955652502
#
#
# 58  ######################################
# AUBENTON % France % Picardie % la Thiérache % l'Aube
# https://www.wikidata.org/wiki/Q274692
# Head  AUBENTON  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aubenton Q274692 0.020684768548646648
#  1  :  canton d'Aubenton Q269779 -0.18541753619882662
#
#
# 59  ######################################
# AUBETERRE % France % l'Angoumois % la Dronne
# https://www.wikidata.org/wiki/Q635709
# Head  AUBETERRE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aubeterre-sur-Dronne Q635709 0.1351300402185598
#  1  :  Aubeterre Q1085483 -0.3126509683697738
#
#
# 60  ######################################
# AUBIGNY % France % le Berry % la Nerre
# https://www.wikidata.org/wiki/Q843114
# Head  AUBIGNY  tagged successfully :
# Distance to truth :  354.8035571986032
#  0  :  Aubigny Q843114 -0.4960283781283259
#  1  :  Aubigny-aux-Kaisnes Q782684 -0.5333135290055037
#  2  :  Aubigny-en-Laonnois Q864448 -0.5356634491301971
# ____________ 3  :  Aubigny Q838623 -0.5475358962695802
#  4  :  Montereau-sur-le-Jard Q243379 -0.5552493392756447
#  5  :  Aubigny Q45720 -0.6022275175014323
#  6  :  Aubigny-les-Pothées Q1020405 -0.625986123114024
#  7  :  Aubigny Q1102940 -0.6686251638342529
#  8  :  Aubigny Q1084361 -0.6884861631082373
#  9  :  Isle-Aubigny Q1374694 -0.7076633063699937
#
#
# 61  ######################################
# AUBUSSON % France % Limosin % la Marche % la Creuse
# https://www.wikidata.org/wiki/Q217161
# Head  AUBUSSON  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aubusson Q217161 -0.021245335703668378
#  1  :  arrondissement d'Aubusson Q700507 -0.14496433536840714
#  2  :  Aubusson Q733754 -0.42798520247567273
#  3  :  canton d'Aubusson Q182582 -0.4559430267874721
#  4  :  Aubusson-d'Auvergne Q1046693 -0.6232227648339136
#  5  :  gare d'Aubusson Q2701026 -0.9032628769266002
#  6  :  Aubusson Q49344825 -0.9264446412669426
#
#
# 62  ######################################
# AUCH % France % Armagnac % Gers % d'Armagnac % la Gascogne
# https://www.wikidata.org/wiki/Q181725
# Head  AUCH  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Auch Q181725 0.3703941554881758
#  1  :  arrondissement d'Auch Q700509 0.008520764311981566
#  2  :  gare d'Auch Q2200917 -0.894378451165174
#  3  :  Auch Q5681472 -0.9258009571924135
#  4  :  station météorologique d'Auch Q117882230 -0.9309858004901463
#  5  :  Avoch Q1011342 -1.1899082713332183
#  6  :  Аух Q4072487 -1.321308588334386
#
#
# 63  ######################################
# AVENAI % France % Champagne % Marne % Rheims
#
#
# 64  ######################################
# AVIGNONET OU VIGNONET % France % Lauragais % Lers % le haut Languedoc
# https://www.wikidata.org/wiki/Q1069612
# Head  AVIGNONET  tagged successfully :
# Distance to truth :  356.3950141607121
#  0  :  Avignonet Q1069612 -0.30944767115968785
#  1  :  gare d'Avignonet Q3095707 -0.6026351865515385
#
#
# 65  ######################################
# AULPS % France % Provence % Fréjus
#
#
# 66  ######################################
# AUMALE OU ALBEMARLE % France % Caux % la haute Normandie
# https://www.wikidata.org/wiki/Q632269
# Head  AUMALE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aumale Q632269 -0.3359588494161624
#  1  :  canton d'Aumale Q241626 -0.3575374951115372
#  2  :  département d'Aumale Q2398454 -0.3967668228749243
#  3  :  Arrondissement d'Aumale Q73644714 -0.6476126617578488
#  4  :  Aumale Q2950369 -0.6634592220700722
#  5  :  Sour El Ghozlane Q312000 -0.6645991242003193
#  6  :  Aumale Q782118 -0.9981617485210068
#  7  :  Aumale Q107308250 -1.0692567364942915
#
#
# 67  ######################################
# AUNEAU % France % Paris % Chartres
# https://www.wikidata.org/wiki/Q637489
# Head  AUNEAU  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Auneau Q637489 -0.268414291812737
#  1  :  canton d'Auneau Q1475568 -0.2746584156504279
#  2  :  gare d’Auneau Q3095696 -0.7103664872951501
#
#
# 68  ######################################
# AVRANCHES % France % Sée % basse Normandie % l'Avranchise
# https://www.wikidata.org/wiki/Q204430
# Head  AVRANCHES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Avranches Q204430 0.10857859323121621
#  1  :  arrondissement d'Avranches Q700557 -0.11616081228171882
#  2  :  canton d'Avranches Q1724331 -0.27410610044076544
#  3  :  Avranches Q66370822 -0.3528738865079051
#  4  :  gare d’Avranches Q2709420 -0.6844464963726653
#  5  :  Avranches Q65227419 -0.7145586571277109
#
#
# 69  ######################################
# AURILLAC % France % la Jordane % la basse Auvergne
# https://www.wikidata.org/wiki/Q174234
# Head  AURILLAC  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Aurillac Q174234 0.32128225395408294
#  1  :  arrondissement d'Aurillac Q700521 0.018048216974648312
#  2  :  aire d'attraction d'Aurillac Q108921173 -0.13757327823048937
#  3  :  gare d’Aurillac Q1860416 -0.6898800303585725
#  4  :  aéroport d'Aurillac Q1430905 -0.7011278566661153
#  5  :  station météorologique d'Aurillac Q117881862 -0.7273866163581303
#
#
# 70  ######################################
# AUTRY % France % Pithiviers % l'Orléanois
# https://www.wikidata.org/wiki/Q990892
# Head  AUTRY  tagged successfully :
# Distance to truth :  229.3542802843091
#  0  :  Autry Q990892 -0.016904036772393827
#
#
# 71  ######################################
# AUTUN % France % Bourgogne % l'Aroux
# https://www.wikidata.org/wiki/Q190827
# Head  AUTUN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Autun Q190827 -0.0960935189100407
#  1  :  arrondissement d'Autun Q662088 -0.2353930283125032
#  2  :  gare d'Autun Q3095701 -0.8081086178345926
#  3  :  station météorologique d'Autun Q117882860 -0.8265015480356568
#  4  :  Autun Q4827206 -1.2418673807096814
#
#
# 72  ######################################
# AUVILLARD % France % Gascogne % la Lomagne % la Garonne
#
#
# 73  ######################################
# AUXERRE % France % Bourgogne % l'Auxerrois % l'Yonne
# https://www.wikidata.org/wiki/Q167600
# Head  AUXERRE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Auxerre Q167600 0.4535169787245037
#  1  :  arrondissement d'Auxerre Q700534 0.020617810268396042
#  2  :  canton d'Auxerre-Est Q1724308 -0.5029045883770609
#
#
# 74  ######################################
# AY % France % Champagne % la Marne
# https://www.wikidata.org/wiki/Q792663
# Head  AY  tagged successfully :
# Distance to truth :  433.9924483832593
#  0  :  Ay Q792663 -0.41552265474355743
#  1  :  Ay Q792669 -0.4339987443759201
# ____________ 2  :  Ay Q658928 -0.44769014849584177
#  3  :  canton d'Ay Q1724334 -0.6209405477075999
#  4  :  Mese Q39768 -0.6957239450681048
#  5  :  Ай-Серез Q4058644 -0.7638751812882181
#  6  :  Ай Q4058705 -0.817903647266155
#  7  :  Aï Q403175 -0.9712143056326024
#  8  :  Междуречье Q4288649 -1.10697407144629
#  9  :  Ай Q4058711 -1.2047743595564597
#
#
# 75  ######################################
# AYEN % France % Limoges % Brives % le Limosin
# https://www.wikidata.org/wiki/Q193133
# Head  AYEN  tagged successfully :
# Distance to truth :  108.78083359353587
#  0  :  Ahun Q193133 -0.48245827420788
# ____________ 1  :  Ayen Q504868 -0.5782973105241638
#  2  :  canton d'Ayen Q1724339 -0.5847289013398185
#  3  :  Ayen Q20913947 -1.3594934978706374
#
#
# 76  ######################################
# AYMARGUES % France % Nîmes % le Languedoc
#
#
# 77  ######################################
# AZAY % France % la Touraine % l'Indre
# https://www.wikidata.org/wiki/Q243032
# Head  AZAY  tagged successfully :
# Distance to truth :  36.74970620712648
#  0  :  Azay-le-Rideau Q243032 0.23679529564173363
#  1  :  Azay, Bafra Q6895667 -1.0610965113608344
#
#
# 78  ######################################
# AZAY-LE-RIDEAU % France % Touraine % Tours
# https://www.wikidata.org/wiki/Q243032
# Head  AZAY-LE-RIDEAU  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Azay-le-Rideau Q243032 0.017841039965542205
#  1  :  canton d'Azay-le-Rideau Q1096757 -0.2507752191572119
#  2  :  Azay-le-Rideau Q3095715 -0.5646845941933876
#
#
# 79  ######################################
# AZILHAN OU AZILLE % France % Narbonne % le Languedoc
# https://www.wikidata.org/wiki/Q199673
# Head  AZILLE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Azille Q199673 0.02057043742237985
#
#
# 80  ######################################
# BACCARAT % France % Lorraine % Nanci % Estival % la Meurte
# https://www.wikidata.org/wiki/Q319282
# Head  BACCARAT  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Baccarat Q319282 -0.15459078366237589
#  1  :  canton de Baccarat Q1724343 -0.24698285298155298
#  2  :  gare de Baccarat Q430790 -0.6709171790615382
#
#
# 81  ######################################
# BAGNERES % France % Bigorre % Gascogne % l'Adour
# https://www.wikidata.org/wiki/Q208264
# Head  BAGNERES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bagnères-de-Bigorre Q208264 0.18890557676631614
#  1  :  Bagnères-de-Luchon Q238393 0.0010483022076170911
#
#
# 82  ######################################
# BAGNOLS % France % la Cese % le bas Languedoc
# https://www.wikidata.org/wiki/Q274183
# Head  BAGNOLS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bagnols-sur-Cèze Q274183 0.4443508895578714
#  1  :  Bagnols Q1617158 0.2388281700499313
#  2  :  Bagnols Q685239 0.04214420156056997
#  3  :  Bagnols-les-Bains Q193113 0.035716147991078695
#
#
# 83  ######################################
# BAIGNEUX % France % Bourgogne % Dijon
# https://www.wikidata.org/wiki/Q22083
# Head  BAIGNEUX  tagged successfully :
# Distance to truth :  199.07906079606244
#  0  :  Vernéville Q22083 0.029335001865192112
#
#
# 84  ######################################
# BALLON % France % Mans % l'Orne
# https://www.wikidata.org/wiki/Q1724363
# Head  BALLON  tagged successfully :
# Distance to truth :  3.3015872955779852
#  0  :  canton de Ballon Q1724363 0.09980118163927476
# ____________ 1  :  Ballon Q749143 -0.12683973276146787
#  2  :  Ballon Q936602 -0.6491810503113027
#  3  :  Ballon Q2277458 -0.6506177953555856
#  4  :  Le Ballon Q31666637 -0.9200176008591954
#  5  :  Ballon Q59718640 -1.1348845881115814
#  6  :  Ballon Q111660935 -1.2066398912855572
#  7  :  aéroport Rodriguez Ballon Q1430861 -1.2078409768529978
#  8  :  Ballon Q104260914 -1.223180989144788
#  9  :  Ballon Q60553392 -1.223415946401409
#
#
# 85  ######################################
# BAPAUME % France % l'Artois
# https://www.wikidata.org/wiki/Q317235
# Head  BAPAUME  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bapaume Q317235 0.21814643072604678
#  1  :  Biefvillers-lès-Bapaume Q998058 -0.053141978999989625
#  2  :  canton de Bapaume Q1724374 -0.08985260661804562
#  3  :  Bapaume Q48807630 -1.2530306350805247
#  4  :  Bapaume Q4857507 -1.2631696770724234
#
#
# 86  ######################################
# BAR-SUR-AUBE % France % Champagne % Vallage
# https://www.wikidata.org/wiki/Q700574
# Head  BAR-SUR-AUBE  tagged successfully :
# Distance to truth :  0.4753983164279755
#  0  :  arrondissement de Bar-sur-Aube Q700574 -0.0786251322541196
# ____________ 1  :  Bar-sur-Aube Q209093 -0.1261918661486423
#  2  :  canton de Bar-sur-Aube Q535865 -0.2949856071914403
#  3  :  gare de Bar-sur-Aube Q687462 -0.6797817676421753
#
#
# 87  ######################################
# BAR-SUR-SEINE % France % Bourgogne
# https://www.wikidata.org/wiki/Q328309
# Head  BAR-SUR-SEINE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bar-sur-Seine Q328309 -0.23607280062825042
#  1  :  canton de Bar-sur-Seine Q972703 -0.27023546371659957
#  2  :  arrondissement de Bar-sur-Seine Q2863703 -0.6513478884653399
#  3  :  Bar-sur-Seine Q120757175 -0.6797614547888344
#
#
# 88  ######################################
# BARBEYRA % France % Carcassonne % le bas Languedoc
#
#
# 89  ######################################
# BARBEZIEUX % France % Saintonge
# https://www.wikidata.org/wiki/Q60882292
# Head  BARBEZIEUX  tagged successfully :
# Distance to truth :  9.676709986354453e-08
#  0  :  Barbezieux Q60882292 -0.3483156916978203
#  1  :  arrondissement de Barbezieux Q2863704 -0.6472818153100914
#  2  :  station météorologique de Barbezieux Q118246450 -0.6736059149283968
#
#
# 90  ######################################
# BARBONNE % France % Champagne % Châlons
#
#
# 91  ######################################
# BARCELONE % France % Guienne % l'Armagnac
# https://www.wikidata.org/wiki/Q1492
# Head  BARCELONE  tagged successfully :
# Distance to truth :  325.15081278061024
#  0  :  Barcelone Q1492 0.6170977293723983
#  1  :  Ville de Barcelone Q31913048 -0.45593439773779165
#  2  :  Barcelone Q58214028 -0.5561907928334016
#  3  :  Place de Barcelone Q110929069 -0.9461657032185373
#
#
# 92  ######################################
# BARCELONETTE % France % le Dauphiné
# https://www.wikidata.org/wiki/Q207577
# Head  BARCELONETTE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barcelonnette Q207577 0.46069734235610005
#
#
# 93  ######################################
# BARENTON % France % Avranches % l'Ardée % la basse Normandie
# https://www.wikidata.org/wiki/Q1001315
# Head  BARENTON  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barenton Q1001315 0.055184450956802245
#  1  :  canton de Barenton Q1724381 0.038673067844798736
#  2  :  Barenton Q49345412 -0.5803421640584515
#
#
# 94  ######################################
# BARFLEUR % France % Normandie % le Cotentin
# https://www.wikidata.org/wiki/Q211684
# Head  BARFLEUR  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barfleur Q211684 0.079132004191806
#  1  :  Barfleur Q49345414 -0.5981094165013618
#  2  :  station météorologique de Barfleur Q117882538 -0.6020625204072658
#
#
# 95  ######################################
# BARGEMONT % France % Fréjus
#
#
# 96  ######################################
# BARJAC % France % Languedoc % d'Usès
# https://www.wikidata.org/wiki/Q1865065
# Head  BARJAC  tagged successfully :
# Distance to truth :  293.5738553746238
#  0  :  Barjac Q1865065 -0.1589232284777855
#  1  :  Barjac Q381311 -0.22287120514339342
# ____________ 2  :  Barjac Q274188 -0.31637493186352605
#  3  :  canton de Barjac Q1724384 -0.43421832433692664
#  4  :  gare de Barjac Q1821673 -0.653327112281155
#
#
# 97  ######################################
# BARJOLS % France % Provence
# https://www.wikidata.org/wiki/Q658840
# Head  BARJOLS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barjols Q658840 0.3960767725163561
#  1  :  canton de Barjols Q585141 0.319515825029955
#
#
# 98  ######################################
# BARRAUX % France % Grésivaudan % le Dauphiné % l'Iser
# https://www.wikidata.org/wiki/Q385282
# Head  BARRAUX  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barraux Q385282 0.12781924245434428
#
#
# 99  ######################################
# BARRE % France % Mende % le Gévaudan
# https://www.wikidata.org/wiki/Q194145
# Head  BARRE  tagged successfully :
# Distance to truth :  534.1148707465131
#  0  :  Château-Thierry Q194145 -0.36383348974543256
#  1  :  La Barre Q816989 -0.4108129294126355
#  2  :  La Barre Q773429 -0.5767000300985425
# ____________ 3  :  Barre-des-Cévennes Q383658 -0.5988437246420318
#  4  :  Barre Q604591 -0.6139673447065022
#  5  :  La Barre-en-Ouche Q1075394 -0.6479576853249258
#  6  :  Barre Q26071 -0.7674531075990759
#  7  :  Machy Q314709 -0.7836210682298301
#  8  :  Barre Q808841 -0.975579238964649
#  9  :  Barre Q3635167 -1.1222220550919697
#
#
# 100  ######################################
# BARREME % France % Asse % d'Asse % la haute Provence
# https://www.wikidata.org/wiki/Q840218
# Head  BARREME  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Barrême Q840218 0.31328110660046904
#  1  :  canton de Barrême Q1724398 -0.30707123865107944
#  2  :  Barrême Q2328223 -0.7066452419100155
#  3  :  station météorologique de Barrême Q118246359 -0.728781855025519
#
#
# 101  ######################################
# BASIEGES % France % Languedoc % Toulouse % Carcassonne
#
#
# 102  ######################################
# BASSEMPOIN % France % la Gascogne
#
#
# 103  ######################################
# BAVEY % France % le Haynault
#
#
# 104  ######################################
# BAUGÉ % France % Anjou % le Coesnon % la Fleche
# https://www.wikidata.org/wiki/Q1240256
# Head  BAUGÉ  tagged successfully :
# Distance to truth :  1.6136126045923656
#  0  :  canton de Baugé Q1240256 -0.14224010063058445
#  1  :  Baugé Q26768 -0.14330529342023335
#  2  :  arrondissement de Baugé Q2863708 -0.5590556997576843
#  3  :  Baugé Q49345569 -0.5838826199559906
#  4  :  Bauge Q117190456 -1.0197098938702942
#
#
# 105  ######################################
# BAUGÉ % France % Mâcon % la Bresse
# https://www.wikidata.org/wiki/Q1240256
# Head  BAUGÉ  tagged successfully :
# Distance to truth :  407.48113086820655
#  0  :  canton de Baugé Q1240256 -0.1256211955262937
#  1  :  Baugé Q26768 -0.12673566442562256
#  2  :  arrondissement de Baugé Q2863708 -0.5420973412774734
#  3  :  Baugé Q49345569 -0.5669001253777552
#  4  :  Bauge Q117190456 -0.9967930869359964
#
#
# 106  ######################################
# BAUGENCI % France % l'Orléanois
#
#
# 107  ######################################
# BAUME LES NONES % France % le Doux % Franche-Comté
# https://www.wikidata.org/wiki/Q582299
# Head  BAUME  tagged successfully :
# Distance to truth :  120.50288280993381
#  0  :  La Baume Q582299 -0.48413268402128556
#  1  :  Baume-les-Messieurs Q675625 -0.5987894945964894
#  2  :  Bauma Q67145 -0.8799445348682344
#  3  :  arrondissement de Baume Q2863710 -0.9259201453723835
#  4  :  Les Balmes Q109572909 -0.9565182523011055
#  5  :  Labaume Q109571289 -0.9569925578347366
#  6  :  Baumé Q4873561 -1.3628336263388534
#  7  :  Bäume (Friedberg) Q58150124 -1.3648257967479145
#
#
# 108  ######################################
# BAYEUX % France % Bessin % Aure % la Normandie
# https://www.wikidata.org/wiki/Q183910
# Head  BAYEUX  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bayeux Q183910 0.30946523969523865
#  1  :  arrondissement de Bayeux Q700609 -0.29121600481221854
#  2  :  canton de Bayeux Q1724414 -0.36042192625324315
#  3  :  Bayon Q2892283 -0.6612578426068997
#  4  :  Bayeux Q2065978 -0.7748864804544779
#  5  :  Bayeux Q2189086 -0.8722206162332211
#  6  :  station météorologique de Bayeux Q118246435 -0.9326764262336289
#  7  :  Bayeux Q18475262 -1.1874727348921434
#  8  :  Bayeux Q22027403 -1.2149852564031813
#
#
# 109  ######################################
# BAZAS % France % Bazadois % Gascogne
# https://www.wikidata.org/wiki/Q208427
# Head  BAZAS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bazas Q208427 -0.10775615017708762
#  1  :  canton de Bazas Q180317 -0.2546123863750771
#  2  :  Arrondissement de Bazas Q2863711 -0.3916341989200445
#  3  :  Bazas Q49345620 -0.5824988622600862
#  4  :  Үлкен Үлкен Базас Q12577505 -1.1526810498162448
#  5  :  Базас Q3726819 -1.1559475962010517
#  6  :  Bazas Q9651964 -1.2234224948456849
#
#
# 110  ######################################
# BEAUFORT % France % Champagne % Montmorenci
# https://www.wikidata.org/wiki/Q1349138
# Head  BEAUFORT  tagged successfully :
# Distance to truth :  619.393850079547
#  0  :  Beaufort Q1349138 -0.4422476380140852
#  1  :  Beaufort Q1158013 -0.47131630875490793
#  2  :  comté de Beaufort Q495682 -0.5373044869544545
#  3  :  canton de Beaufort Q1472755 -0.5397251561292384
#  4  :  Beaufort Q18693153 -0.6803137461052512
#  5  :  Beaufort Q813376 -0.7041804481086248
#  6  :  Beaufort Q813374 -0.7349402695842078
#  7  :  Alberni-Clayoquot B Q117074622 -0.8570723835865021
#  8  :  Beaufort Q16762558 -0.8947961799001065
#  9  :  Beaufort Q813371 -0.9007684366509884
#
#
# 111  ######################################
# BEAUJEU % France % le Beaujolois % l'Ardiere
# https://www.wikidata.org/wiki/Q740693
# Head  BEAUJEU  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Beaujeu Q740693 0.08058290848486505
#  1  :  Beaujeu Q473288 0.01631030600425354
#  2  :  canton de Beaujeu Q163762 -0.18736309932160555
#  3  :  arrêt Beaujeu Q56857087 -0.5918509487972976
#  4  :  De Beaujeu Q112855061 -1.314781335798164
#  5  :  De Beaujeu Q63242956 -1.3155324125763497
#  6  :  De Beaujeu Q61021420 -1.3167842072066596
#
#
# 113  ######################################
# BEAUMARCHES % France % Ausch % d'Ausch % Riviere-Verdun
# https://www.wikidata.org/wiki/Q1041910
# Head  BEAUMARCHES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Beaumarchés Q1041910 0.5947283470449052
#
#
# 114  ######################################
# BEAUNE % France % Bourgogne
# https://www.wikidata.org/wiki/Q16121
# Head  BEAUNE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Beaune Q16121 -0.1159095221963834
#  1  :  arrondissement de Beaune Q14812 -0.1832352366332617
#  2  :  canton de Beaune Q17174705 -0.5558564224494829
#  3  :  Saint-Michel-de-Maurienne Q910079 -0.5949962121016412
#  4  :  Beaune Q2535260 -0.6676529751490162
#  5  :  Beaune Q15720687 -0.7184527760070059
#  6  :  Beaune Q83272406 -0.9090996871561969
#  7  :  Beaune Q112864324 -0.9223078221762231
#  8  :  Beaune Q2893254 -0.9947151377772041
#
#
# 115  ######################################
# BEAUVAIS % France % Beauvoisis % France % le Therain
# https://www.wikidata.org/wiki/Q174257
# Head  BEAUVAIS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Beauvais Q174257 -0.003932197506405943
#  1  :  arrondissement de Beauvais Q534383 -0.34770610105605215
#  2  :  Beauvais Q2204667 -0.5775649300201632
#  3  :  Beauvais Q84321409 -0.62529630268111
#  4  :  Saint-Barthélemy-d'Agenais Q1108544 -0.7393122204391593
#  5  :  Beauvais Q109574821 -0.9710368024842374
#  6  :  Beauvais Q106682376 -0.97150591962519
#  7  :  Beauvais Q63242441 -1.5262188932864555
#
#
# 116  ######################################
# BEAUVOIR-SUR-MER % France % Poitou
# https://www.wikidata.org/wiki/Q1023635
# Head  BEAUVOIR-SUR-MER  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Beauvoir-sur-Mer Q1023635 -0.1514021267573331
#  1  :  canton de Beauvoir-sur-Mer Q175432 -0.20819752334177455
#  2  :  Beauvoir-sur-Mer Q49345751 -0.5636985416615188
#
#
# 117  ######################################
# BEDARIEUX OU BEC D'ARIEUX % France % Beziers % le Languedoc % d'Obe
# https://www.wikidata.org/wiki/Q274412
# Head  BEDARIEUX  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Bédarieux Q274412 0.086431020250613
#  1  :  canton de Bédarieux Q1340821 -0.24723225187774645
#  2  :  gare de Bédarieux Q3096097 -0.5439528933435462
#  3  :  station météorologique de Bédarieux Q117882263 -0.6381165288810028
#
#
# 118  ######################################
# BEFORT % France % Sundgaw
# https://www.wikidata.org/wiki/Q18693153
# Head  BEFORT  tagged successfully :
# Distance to truth :  247.87658049373104
#  0  :  Beaufort Q18693153 0.21626384784284403
#  1  :  Beaufort Q16762558 -0.014858738429619489
#
#
# 119  ######################################
# BEIRE % France % Bourgogne % Dijon
# https://www.wikidata.org/wiki/Q814864
# Head  BEIRE  tagged successfully :
# Distance to truth :  767.876945736741
#  0  :  Beire (Navarre) Q814864 -0.6068635105831792
#  1  :  Beuren Q80725 -0.6445754553450875
#  2  :  Beire Q814844 -0.7121206920203316
#  3  :  Barroselas e Carvoeiro Q17515103 -0.806305348750226
# ...
# Head  VILLE  tagged successfully :
# Distance to truth :  746.8368966450266
#  0  :  Villé Q21606 -0.5739974615203849
#  1  :  Jacksonville Q16568 -0.6052361529187621
#  2  :  La Ville Q18326111 -0.8041238234477207
#  3  :  Ville Q1165252 -0.8193686352551475
#  4  :  canton de Villé Q1398456 -0.8376929072600079
#  5  :  Villers Q903361 -0.8569991580574703
#  6  :  Ormes-et-Ville Q194806 -0.8795823215202343
#  7  :  Ville-Langy Q27713 -0.9209068765882678
#  8  :  La Ville Q113238293 -0.929294517258828
#  9  :  Ville Q1243933 -1.08901863182721
#
#
# 844  ######################################
# VILLE-FRANCHE % France % Rodès % Cahors % Montauban % Rouergue % Toulouse % Narbonne % le Rouergue % la basse-Marche % l'Avéiron
# https://www.wikidata.org/wiki/Q21606
# Head  VILLE  tagged successfully :
# Distance to truth :  600.8488654889353
#  0  :  Villé Q21606 -0.3967971880258524
#  1  :  Jacksonville Q16568 -0.47650338465006525
#  2  :  La Ville Q18326111 -0.6296445061051846
#  3  :  Ville Q1165252 -0.6440380549020693
#  4  :  canton de Villé Q1398456 -0.6630588530503732
#  5  :  Villers Q903361 -0.6819704302172485
#  6  :  Ormes-et-Ville Q194806 -0.7047215573692183
#  7  :  Ville-Langy Q27713 -0.7463735996573246
#  8  :  La Ville Q113238293 -0.755693029625688
#  9  :  Ville Q1243933 -0.9684437222695983
#
#
# 845  ######################################
# VILLE-FRANCHE DE PANAT % France % Dordon % Tarn % Rodès % Milhau % le Rouergue
# https://www.wikidata.org/wiki/Q21606
# Head  VILLE  tagged successfully :
# Distance to truth :  591.0857924464186
#  0  :  Villé Q21606 -0.4351107268052474
#  1  :  Jacksonville Q16568 -0.5465302373412311
#  2  :  La Ville Q18326111 -0.6712329818420487
#  3  :  Ville Q1165252 -0.6846317981909373
#  4  :  canton de Villé Q1398456 -0.7044764986681015
#  5  :  Villers Q903361 -0.7229305501170532
#  6  :  Ormes-et-Ville Q194806 -0.7458880975125981
#  7  :  Ville-Langy Q27713 -0.7879378899152352
#  8  :  La Ville Q113238293 -0.7983546326532543
#  9  :  Ville Q1243933 -1.0494708350198838
#
#
# 846  ######################################
# VILLE-FRANCHE % France % Argonne % Stenay % la Champagne % la Meuse
# https://www.wikidata.org/wiki/Q21606
# Head  VILLE  tagged successfully :
# Distance to truth :  197.6168482159758
#  0  :  Villé Q21606 -0.4952623484135669
#  1  :  Jacksonville Q16568 -0.585433082496892
#  2  :  La Ville Q18326111 -0.7299832879098026
#  3  :  Ville Q1165252 -0.743803695519023
#  4  :  canton de Villé Q1398456 -0.7632978140994563
#  5  :  Villers Q903361 -0.7819452657034223
#  6  :  Ormes-et-Ville Q194806 -0.8048139061356006
#  7  :  Ville-Langy Q27713 -0.8466930219330779
#  8  :  La Ville Q113238293 -0.8566435134302883
#  9  :  Ville Q1243933 -1.0836819221079836
#
#
# 847  ######################################
# VILLE-MAUR % France % Champagne % Chaumont
# https://www.wikidata.org/wiki/Q16568
# Head  VILLE  tagged successfully :
# Distance to truth :  7240.695124284254
#  0  :  Jacksonville Q16568 -0.3309919666877249
#  1  :  Villé Q21606 -0.38457056769892206
#  2  :  La Ville Q18326111 -0.6207516560980817
#  3  :  Ville Q1165252 -0.6341329059301349
#  4  :  canton de Villé Q1398456 -0.6539922605956163
#  5  :  Villers Q903361 -0.6724382705923321
#  6  :  Ormes-et-Ville Q194806 -0.6953995700195104
#  7  :  Ville-Langy Q27713 -0.7374565440595481
#  8  :  La Ville Q113238293 -0.7478927536757669
#  9  :  Ville Q1243933 -0.830094404701951
#
#
# 848  ######################################
# VILLE-MUR % France % Montauban % Joyeuse % l'Albigeois % le Tarn % le Tarn % le haut Languedoc
# https://www.wikidata.org/wiki/Q16568
# Head  VILLE  tagged successfully :
# Distance to truth :  7233.499104142403
#  0  :  Jacksonville Q16568 -0.35424794795486525
#  1  :  Villé Q21606 -0.4427038120122278
#  2  :  La Ville Q18326111 -0.6764333848919823
#  3  :  Ville Q1165252 -0.6905557138141398
#  4  :  canton de Villé Q1398456 -0.7098000374489633
#  5  :  Villers Q903361 -0.7285864582489842
#  6  :  Ormes-et-Ville Q194806 -0.7513927286872012
#  7  :  Ville-Langy Q27713 -0.7931515355338749
#  8  :  La Ville Q113238293 -0.8027692053884057
#  9  :  Ville Q1243933 -0.8462374836993896
#
#
# 850  ######################################
# VILLENAUX % France % Troyes % la Champagne
#
#
# 851  ######################################
# VILLEPINTE % France % Saint-Papoul % le haut Languedoc
# https://www.wikidata.org/wiki/Q241064
# Head  VILLEPINTE  tagged successfully :
# Distance to truth :  632.1885973284452
#  0  :  Villepinte Q241064 -0.215293075490665
# ____________ 1  :  Villepinte Q843208 -0.46222641390682884
#  2  :  canton de Villepinte Q268811 -0.4816881773521031
#  3  :  Villepinte Q2619128 -0.815118908358134
#  4  :  arrêt Villepinte Q56857607 -0.8706716383397677
#
#
# 852  ######################################
# VILLEPREUX % France % Versailles % le Hurepois
# https://www.wikidata.org/wiki/Q491492
# Head  VILLEPREUX  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Villepreux Q491492 0.4677575643095575
#
#
# 853  ######################################
# VIRE % France % Bocage % Caën % Caen % Paris % Vaudevilles % la basse Normandie % Vire % Rome % France % Paris % Despréaux % Alcippe % Desmares % S. Roch % Luynes % Liancourt % Liancourt % Vire % Astrologie % Allemagne % Angleterre % Hollande % Biblia % Fontenelle % Vire % Rome % Noailles % France % Noailles % Le Tellier % la Fleche % la Chaise % Noailles % Maintenon
# https://www.wikidata.org/wiki/Q702799
# Head  VIRE  tagged successfully :
# Distance to truth :  0.5849248246337276
#  0  :  arrondissement de Vire Q702799 -0.569785704752988
#  1  :  Vire Q1346326 -0.6543007419260696
# ____________ 2  :  Vire Q220684 -0.6683829760551904
#  3  :  canton de Vire Normandie Q948749 -0.8840736402703536
#  4  :  Elle Q1331752 -0.9125726977271196
#  5  :  Viré-en-Champagne Q743459 -0.9145030498646105
#  6  :  Wyre (Angleterre) Q894100 -0.9195468080504204
#  7  :  Viré Q1462798 -0.9444636027101583
#  8  :  Vire Q2311613 -1.0908873543258166
#  9  :  Vire-sur-Lot Q922210 -1.1603109121177935
#
#
# 854  ######################################
# VITRÉ % France % Rennes % Nantes % Saint-Malo % Rennes % la Bretagne % la Vilaine % Bretagne % Bretagne
# https://www.wikidata.org/wiki/Q234704
# Head  VITRÉ  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Vitré Q234704 -0.4879726853842924
#  1  :  Vitray Q260079 -0.7921127270607609
#  2  :  Vitrey Q1161684 -0.8148720551935187
#  3  :  canton de Vitré-Est Q571558 -0.8517971921035032
#  4  :  Vitré Q1348699 -0.9005731558036376
#  5  :  arrondissement de Vitré Q2864083 -1.031777169442005
#  6  :  Vitré Q49370263 -1.1235421926048088
#  7  :  Vitré Q2330319 -1.1853383044036612
#  8  :  Vitré Q49370265 -1.237311722616872
#  9  :  Vitre Q12955803 -1.3517087598699384
#
#
# 855  ######################################
# VITRI-LE-BRÛLÉ % France % Saulx % Vitry % Perthois % Champagne % Rheims % Vitry % la Champagne % Thibaud % Vitry % le Brûlé % Vitri % Luxembourg % Montcontour % Vitri-le-François % la Marne
# https://www.wikidata.org/wiki/Q333049
# No coordinates found in JSON from uri  Q333049
# missing coordinates
# Head  BRÛLÉ  tagged successfully :
# Distance to truth :  None
#  0  :  Lakotas Q333049 -0.5177255488400268
#  1  :  Brule Q4978769 -0.6165736709996441
#  2  :  Brûlés Q992401 -0.7259735723793102
#  3  :  Brule Q2926542 -0.9228144994592142
#  4  :  Le Brûlé Q3220649 -0.9783511333412303
#  5  :  Brule Q731766 -1.042642849024476
#  6  :  Brule Q1658260 -1.058962929763803
#  7  :  Brule Q4978760 -1.1074370710857315
#  8  :  Bruul (straatnaam) Q122944070 -1.1166806037868966
#  9  :  Brûlé Q2927338 -1.1319269042948603
#
#
# 856  ######################################
# VITRI-LE-FRANÇOIS % France % Châlons % Bar-le-Duc % Paris % la Champagne % la Marne % Vitri-le-Brûlé % Vitri % Pertois %  %  %  % Vitri-le-François % Paris % Nantes % Angleterre % Devonshire % l'Europe % la Société % la Société royale % Cardan % Montmort % Montmort % la Société royale %  %  % Paris
# https://www.wikidata.org/wiki/Q282944
# Head  FRANÇOIS  tagged successfully :
# Distance to truth :  7006.245975411174
#  0  :  Le François Q282944 -0.6205261793546311
#  1  :  François Q542035 -0.796407614093271
#  2  :  Le François Q27729199 -1.3514726928348293
#  3  :  François Q49350515 -1.3514726928348293
#  4  :  Le François Q90853864 -1.3521819215838717
#  5  :  François Q5484627 -1.4659362174809465
#  6  :  Francois Q56293625 -1.4866409901783637
#
#
# 857  ######################################
# VITTEAUX % France % Sémur % Bourgogne % Dijon % Sémur % la Bourgogne % la Braine % Vitteaux % Wittemberg % Saxe % Allemagne % Anvers % Saxe % Irlande % Bayle % d'Orange % Thou % Bade % la Mare % Plessis Mornay
# https://www.wikidata.org/wiki/Q137196
# Head  VITTEAUX  tagged successfully :
# Distance to truth :  1.0505266741395198
#  0  :  canton de Vitteaux Q137196 -0.43899745595472944
# ____________ 1  :  Vitteaux Q380877 -0.46325138557543927
#
#
# 858  ######################################
# VIVIERS % France % Languedoc % Vivarais % Rhône % Saint-Esprit % Valence % Jacobines % Vienne % Vivarium % Suabe % Viviers % Viviers % France % Languedoc
# https://www.wikidata.org/wiki/Q274774
# Head  VIVIERS  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Viviers Q274774 -0.22324109315725782
#  1  :  Viviers Q21655 -0.32294202738874767
#  2  :  Viviers Q130184 -0.3762702156295131
#  3  :  canton de Viviers Q1727973 -0.524812479236056
#  4  :  Viviez Q1429355 -0.6024857157160033
#  5  :  Viviers-du-Lac Q549492 -0.6461594114786077
#  6  :  Tercillat Q1012062 -0.7097006296822626
#  7  :  Viviès Q658236 -0.8467575993384859
#  8  :  Viviers Q109410153 -1.119593842697587
#  9  :  Les Viviers Q113373689 -1.2162336606210582
#
#
# 859  ######################################
# VIVONNE % France % Poitiers % Lusignan % le Poitou % le Clain % France % Vivonne % Paris
# https://www.wikidata.org/wiki/Q1613150
# Head  VIVONNE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Vivonne Q1613150 -0.23469454280157365
#  1  :  canton de Vivonne Q1727971 -0.24491950548566743
#  2  :  gare de Vivonne Q2314920 -0.7585651812658145
#
#
# 860  ######################################
# VODABLE % France % Issoire % Auvergne % Auvergne % Auvergne % l'Auvergne % le Dauphiné % le Dauphiné
# https://www.wikidata.org/wiki/Q667255
# Head  VODABLE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Vodable Q667255 -0.7035799453023797
#
#
# 861  ######################################
# VOUGLE % France % Poitiers % Visigoths % Clovis % Pyrénées % le Poitou % la Loire
#
#
# 862  ######################################
# USSEL % France % Ventadour % le Limousin
# https://www.wikidata.org/wiki/Q18101
# Head  USSEL  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Ussel Q18101 -0.24879304489035992
#  1  :  arrondissement d'Ussel Q702689 -0.2600333161166688
#  2  :  Ussel Q809478 -0.4631257260493402
#  3  :  canton d'Ussel-Est Q1308191 -0.47652729589827225
#  4  :  Ussel Q645806 -0.5390429933575653
#  5  :  Ussel Q10328 -0.567347765303361
#  6  :  gare d'Ussel Q2560767 -0.802121058884352
#  7  :  Ussel Q2502589 -0.810841052269101
#  8  :  Ussel Q18495984 -1.2844749808928957
#
#
# 863  ######################################
# UZEL % France % Bretagne % S. Brieux
# https://www.wikidata.org/wiki/Q728614
# Head  UZEL  tagged successfully :
# Distance to truth :  0.16780337466416143
#  0  :  Uzel Q728614 -0.14951331826706893
#  1  :  canton d'Uzel Q26900 -0.3168139064682216
# ____________ 2  :  Uzel Q49369779 -0.4401586608022603
#  3  :  gare d'Uzel Q3095855 -0.6145823391016594
#
#
# 864  ######################################
# WANGEN % France % Strasbourg % la basse-Alsace
# https://www.wikidata.org/wiki/Q21794
# Head  WANGEN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Wangen Q21794 -0.2521094547261823
#  1  :  Wangen im Allgäu Q165015 -0.30494941057115865
#  2  :  Wangen Q1469016 -0.5747975408858164
#  3  :  arrondissement de Wangen Q1803528 -0.697360073031565
#  4  :  Wangen Q66707 -0.7604183883444884
#  5  :  Wangen-Brüttisellen Q66829 -0.7998811716027918
#  6  :  Wangen Q80795 -0.8149547358405913
#  7  :  Wangen an der Aare Q67536 -0.8335130967363567
#  8  :  Wangen bei Olten Q69967 -0.8454397673117178
#  9  :  district de Wangen Q666231 -0.9150429163785773
#
#
# 866  ######################################
# WASSELONNE % France % Alsace % Wasselenheim
# https://www.wikidata.org/wiki/Q22413
# Head  WASSELONNE  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Wasselonne Q22413 0.20432971140208833
#  1  :  canton de Wasselonne Q1398654 0.004846675664897937
#
#
# 867  ######################################
# WATTEN % France % Bourbourg % la Flandre % l'An
# https://www.wikidata.org/wiki/Q742424
# Head  WATTEN  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Watten Q742424 0.06395368213713448
#  1  :  station météorologique de Watten Q117882672 -0.54660095953622
#  2  :  Watten Q2726131 -0.6148974058052662
#  3  :  Watten Q68816757 -0.6971141593008631
#  4  :  Watten Q115263112 -0.8740362497556395
#
#
# 868  ######################################
# WATWEIL % France % Alsace % Sultz
#
#
# 869  ######################################
# WEST-HOFFEN % France % la basse-Alsace
# https://www.wikidata.org/wiki/Q6655
# No coordinates found in JSON from uri  Q6655
# missing coordinates
# Head  WEST  tagged successfully :
# Distance to truth :  None
#  0  :  UTC+01:00 Q6655 1.1346994134601025
#  1  :  heure d'Europe de l'Ouest Q843589 -0.24424887451568988
#  2  :  civilisation occidentale Q160381 -0.24898369547511545
#  3  :  Ouest Q165784 -0.4315280327533031
#  4  :  Heure d'été d'Europe de l'Ouest Q7987828 -0.5383379159252695
#  5  :  conquête de l'Ouest Q14947899 -0.7175863921792475
#  6  :  West (Francfort-sur-le-Main) Q1444866 -0.7433092712045463
#  7  :  Stuttgart-West Q2359473 -0.7460297047263985
#  8  :  Stadtbezirk 4 West (Bremen) Q30147399 -0.7654122173363681
#  9  :  West Q28050950 -0.998050432869253
#
#
# 870  ######################################
# WILER OU WEYLER % France % Schlestat % l'Alsace % la Lorraine
# https://www.wikidata.org/wiki/Q21549
# Head  WILER  tagged successfully :
# Distance to truth :  68.27128401389508
#  0  :  Harskirchen Q21549 0.05808474844761402
#  1  :  Bärschwil Q66716 -0.5059474177166166
#  2  :  Seedorf Q66928 -0.5103164541221759
#  3  :  Wiler Q67489 -0.5433581713915985
#  4  :  Sigriswil Q65732 -0.5630688127292862
#  5  :  Buch am Irchel Q68451 -0.6002909493934188
#  6  :  Rüeggisberg Q66387 -0.6011278485394349
#  7  :  Därstetten Q65721 -0.6128256152503981
#  8  :  Wiler Q15964295 -0.849075383990668
#  9  :  Wiler Q56257557 -0.8996758821226545
#
#
# 871  ######################################
# WORDT % France % Hanau % Wasgaw % la basse-Alsace % Hanau Liectenberg
#
#
# 872  ######################################
# XAINTES % France % la Saintonge
# https://www.wikidata.org/wiki/Q191126
# Head  XAINTES  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Saintes Q191126 0.5354153618442896
#
#
# 873  ######################################
# SAINT YRIER DE LA PERCHE, SAINT % France % le Limousin % l'Ill
# https://www.wikidata.org/wiki/Q127243
# Head  SAINT  tagged successfully :
# Distance to truth :  462.75646035497397
#  0  :  Le Saint Q127243 -0.6295688730829578
#  1  :  Le Saint Q35714305 -0.88897357771509
#  2  :  Le Saint-Fût Q66124040 -1.3032145531757753
#
#
# 874  ######################################
# YVETOT % France % Normandie % Caux % Caudebec % Rouen % Bellay % Marcel % S. Vandreville % Yvetot % Soissons % Yvetot % la France % Yvetot % Yvetot % Yvetot % Vertot % Yvetot % la France % Yvetot % Man % Irlande % l'Angleterre % Yvetot % Caux % Yvetot % Yvetot % Paris % la Roque % la France
# https://www.wikidata.org/wiki/Q691278
# Head  YVETOT  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Yvetot Q691278 -0.3651448397529673
#  1  :  canton d'Yvetot Q1423832 -0.5162800669431732
#  2  :  gare d'Yvetot Q2411757 -1.0897138305861702
#  3  :  arrondissement d'Yvetot Q2863695 -1.226105526120851
#
#
# 875  ######################################
# YVOY, OU IVOY % France % Chier % Sédan % Luxembourg % Riswick % Carignan % la France % le Luxembourg françois
# https://www.wikidata.org/wiki/Q624330
# Head  IVOY  tagged successfully :
# Distance to truth :  0.0
# ____________ 0  :  Carignan Q624330 0.3396613455169901
#  1  :  Ivoy Q3156352 -1.0005140290501182

# %%
# amount of distances below 50 kms in colums 'TapiocaDist2Truth'
print(VILLESFR[VILLESFR['TapiocaDist2Truth'] < 50].shape[0]/VILLESFR.shape[0])
# 20
print(VILLESFR[VILLESFR['TapiocaDist2Truth'] < 20].shape[0]/VILLESFR.shape[0])
# Out:
# 0.5883777239709443
# 0.5799031476997578

# %%
for idx,row in VILLESFR.iterrows():
    if row['TapiocaPredictions']:
        mention = row['TapiocaPredictions']
        tags = [tag['id']for tag in mention['tags']]
        if row['truthyV'] in tags:
            VILLESFR.loc[idx, 'TapiocaTruthInPred'] = True
        else:
            VILLESFR.loc[idx, 'TapiocaTruthInPred'] = False
    else:
        VILLESFR.loc[idx, 'TapiocaTruthInPred'] = False

# %%
VILLESFR['TapiocaTruthInPred'].value_counts(normalize=True)
# Out:
# TapiocaTruthInPred
# True     0.639225
# False    0.360775
# Name: proportion, dtype: float64

# %%
size = VILLESFR.shape[0]
onecandidate = VILLESFR.TapiocaPredictions.notna().sum()
truthinpred = VILLESFR.TapiocaTruthInPred.sum()
print(onecandidate/size)
print(truthinpred/size)
# Out:
# 0.847457627118644
# 0.639225181598063

# %%
VILLESFR.to_json('/home/antoine/Documents/GitHub/toponym-disambiguation/data/VILLESFR_040324_frenchtapiocapreds.json')

# %% [markdown]
# # fame-Baseline

# %%
import pandas as pd
VILLESFR = pd.read_json('/home/antoine/Documents/GitHub/toponym-disambiguation/data/VILLESFR_040324_frenchtapiocapreds.json')

# %%
sample = VILLESFR.sample(1)
m = sample['TapiocaPredictions'].values[0]
m
# Out:
# {'best_qid': None,
#  'best_tag_label': None,
#  'end': 7,
#  'log_likelihood': 16.8399475151,
#  'phrase': 'ALENCON',
#  'start': 0,
#  'tags': [{'aliases': ['Arrondissement Alençon',
#     'Arrondissement de Alencon',
#     '阿朗松区',
#     'Alanson (rayon)',
#     'arrondissement Alencon',
#     'Alençon Kūn',
#     'Arondismento Alençon',
#     "arrondissement d'Alencon",
#     'Qarku Alençon',
#     'Алансон (округ)',
#     'Distrito de Alençon',
#     'Alençoneko barrutia',
#     "Districte d'Alençon",
#     'arondisamant Alençon',
#     'διαμέρισμα του Αλανσόν',
#     'Alençon (arrondissement)',
#     'Okręg Alençon',
#     'Алансон',
#     'arrondissement Alençon',
#     "Arrondissement d'Alençon",
#     'Distrito de Alencon',
#     'Alençon',
#     'arrondissement di Alençon',
#     'بخش الانسون',
#     'Arrondissement de Alençon',
#     'Arondismentul Alençon',
#     'arrondissement of Alençon'],
#    'desc': 'arrondissement français',
#    'edges': [142,
#     12679,
#     181269,
#     969511,
#     1469266,
#     1724770,
#     1725080,
#     1290284,
#     1725603,
#     388898,
#     1432105,
#     1726642,
#     1484960,
#     1724084,
#     39825,
#     39825,
#     39825,
#     39825,
#     96406487,
#     96406455,
#     700557,
#     700472,
#     701822,
#     701616,
#     701660],
#    'extra_aliases': None,
#    'id': 'Q700385',
#    'label': "arrondissement d'Alençon",
#    'nb_sitelinks': 27,
#    'nb_statements': 38,
#    'rank': 7.0422061998,
#    'score': -0.2153911999,
#    'similarities': [{'tag': [0, 7, 'Q700385'], 'score': 0.011219147300000001},
#     {'tag': [10, 16, 'Q142'], 'score': 0.0478870606},
#     {'tag': [10, 16, 'Q70972'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q70802'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q5478259'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q207162'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q2986910'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q168466'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q2946657'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q27827753'], 'score': 0.0110508601},
#     {'tag': [10, 16, 'Q31406071'], 'score': 0.0110508601},
#     {'tag': [22, 27, 'Q12740'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q217459'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q12050959'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q26702029'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q21764720'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q32146472'], 'score': 0.0103777113},
#     {'tag': [22, 27, 'Q29788247'], 'score': 0.0103777113},
#     {'tag': [33, 48, 'Q16954'], 'score': 0.009760658200000001},
#     {'tag': [51, 58, 'Q700385'], 'score': 0.0670905011},
#     {'tag': [51, 58, 'Q181269'], 'score': 0.0670905011},
#     {'tag': [51, 58, 'Q2390674'], 'score': 0.0087509349},
#     {'tag': [51, 58, 'Q109572628'], 'score': 0.0087509349},
#     {'tag': [51, 58, 'Q117882682'], 'score': 0.0087509349},
#     {'tag': [51, 58, 'Q2875357'], 'score': 0.0087509349},
#     {'tag': [61, 68, 'Q700385'], 'score': 0.062789828},
#     {'tag': [61, 68, 'Q181269'], 'score': 0.062789828},
#     {'tag': [61, 68, 'Q2390674'], 'score': 0.0081899776},
#     {'tag': [61, 68, 'Q109572628'], 'score': 0.0081899776},
#     {'tag': [61, 68, 'Q117882682'], 'score': 0.0081899776},
#     {'tag': [61, 68, 'Q2875357'], 'score': 0.0081899776},
#     {'tag': [71, 77, 'Q700664'], 'score': 0.0076290202},
#     {'tag': [71, 77, 'Q18105'], 'score': 0.0076290202},
#     {'tag': [142, 149, 'Q181269'], 'score': 0.0279543755},
#     {'tag': [142, 149, 'Q2390674'], 'score': 0.0036462229},
#     {'tag': [142, 149, 'Q109572628'], 'score': 0.0036462229},
#     {'tag': [142, 149, 'Q117882682'], 'score': 0.0036462229},
#     {'tag': [142, 149, 'Q2875357'], 'score': 0.0036462229},
#     {'tag': [162, 167, 'Q511991'], 'score': 0.0025243082},
#     {'tag': [162, 167, 'Q328304'], 'score': 0.0025243082},
#     {'tag': [162, 167, 'Q111745127'], 'score': 0.0025243082},
#     {'tag': [170, 176, 'Q700664'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q18105'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q1219700'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q1724455'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q17174792'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q1078637'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q1092033'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q60882343'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q2342378'], 'score': 0.0020755423},
#     {'tag': [170, 176, 'Q109576627'], 'score': 0.0020755423},
#     {'tag': [179, 188, 'Q452697'], 'score': 0.0015706806},
#     {'tag': [179, 188, 'Q95172743'], 'score': 0.0015706806},
#     {'tag': [202, 209, 'Q700385'], 'score': 0.0021503366000000003},
#     {'tag': [202, 209, 'Q181269'], 'score': 0.0021503366000000003},
#     {'tag': [202, 209, 'Q2390674'], 'score': 0.0002804787},
#     {'tag': [202, 209, 'Q109572628'], 'score': 0.0002804787},
#     {'tag': [202, 209, 'Q117882682'], 'score': 0.0002804787},
#     {'tag': [202, 209, 'Q2875357'], 'score': 0.0002804787}],
#    'types': {'Q618123': True},
#    'valid': None},
#   {'aliases': ['Ալենսոն',
#     'Αλανσόν',
#     'อาล็องซง',
#     'الانسون',
#     'Alasona',
#     'Alenconium',
#     'อลองซง',
#     'Alenzón',
#     'Alansonas',
#     'Montsort',
#     'Аленсон',
#     'Alesona',
#     'アランソン公爵',
#     'Alenconii',
#     '阿朗松',
#     'Алонсон',
#     'Alansona',
#     'アランソン公',
#     'Alensono',
#     'النسون',
#     '알랑송',
#     'Alencon',
#     'Alanson',
#     'ألونسون',
#     'ალანსონი',
#     'Алансон',
#     'Alencon (stad)',
#     'Courteilles',
#     'الونسون',
#     'আলঁসোঁ',
#     'アランソン',
#     'Perseigne',
#     'Alensona',
#     'Alenzon',
#     'אלנסון'],
#    'desc': "ville et commune française (chef-lieu du département de l'Orne en Normandie)",
#    'edges': [9220524,
#     810196,
#     497572,
#     281000,
#     498219,
#     5190499,
#     142,
#     6655,
#     1777301,
#     6723,
#     36669,
#     12679,
#     1724084,
#     700385,
#     8042892,
#     8725809,
#     12679,
#     700385,
#     969511,
#     1469266,
#     1724084,
#     8876818,
#     150,
#     195473,
#     1098017,
#     1060068,
#     953808,
#     277107,
#     921903,
#     653705,
#     1219850,
#     28087916,
#     1847149,
#     39825,
#     39825,
#     39825,
#     39825,
#     20078554,
#     27658048,
#     19180675,
#     24730793,
#     602358,
#     24329460,
#     2041543,
#     23852266,
#     3181656,
#     736600,
#     2925056,
#     58621108,
#     39825,
#     39825,
#     108921140,
#     3550908,
#     112226256,
#     87711223,
#     112166113,
#     112111570,
#     150,
#     123074299],
#    'extra_aliases': None,
#    'id': 'Q181269',
#    'label': 'Alençon',
#    'nb_sitelinks': 81,
#    'nb_statements': 113,
#    'rank': 6.5886466395,
#    'score': -0.085295545,
#    'similarities': [{'tag': [0, 7, 'Q181269'], 'score': 0.0108616944},
#     {'tag': [10, 16, 'Q142'], 'score': 0.046361332400000003},
#     {'tag': [10, 16, 'Q70972'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q70802'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q5478259'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q207162'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q2986910'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q168466'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q2946657'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q27827753'], 'score': 0.010698769},
#     {'tag': [10, 16, 'Q31406071'], 'score': 0.010698769},
#     {'tag': [22, 27, 'Q12740'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q217459'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q12050959'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q26702029'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q21764720'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q32146472'], 'score': 0.0100470673},
#     {'tag': [22, 27, 'Q29788247'], 'score': 0.0100470673},
#     {'tag': [33, 48, 'Q16954'], 'score': 0.0094496741},
#     {'tag': [51, 58, 'Q700385'], 'score': 0.06495293270000001},
#     {'tag': [51, 58, 'Q181269'], 'score': 0.06495293270000001},
#     {'tag': [51, 58, 'Q2390674'], 'score': 0.036712527200000004},
#     {'tag': [51, 58, 'Q109572628'], 'score': 0.0084721217},
#     {'tag': [51, 58, 'Q117882682'], 'score': 0.0084721217},
#     {'tag': [51, 58, 'Q2875357'], 'score': 0.0084721217},
#     {'tag': [61, 68, 'Q700385'], 'score': 0.0607892831},
#     {'tag': [61, 68, 'Q181269'], 'score': 0.0607892831},
#     {'tag': [61, 68, 'Q2390674'], 'score': 0.03435916},
#     {'tag': [61, 68, 'Q109572628'], 'score': 0.0079290369},
#     {'tag': [61, 68, 'Q117882682'], 'score': 0.0079290369},
#     {'tag': [61, 68, 'Q2875357'], 'score': 0.0079290369},
#     {'tag': [71, 77, 'Q700664'], 'score': 0.0073859522},
#     {'tag': [71, 77, 'Q18105'], 'score': 0.0073859522},
#     {'tag': [71, 77, 'Q1219700'], 'score': 0.0073859522},
#     {'tag': [71, 77, 'Q1724455'], 'score': 0.0073859522},
#     {'tag': [71, 77, 'Q17174792'], 'score': 0.0073859522},
#     {'tag': [142, 149, 'Q117882682'], 'score': 0.0035300507},
#     {'tag': [142, 149, 'Q2875357'], 'score': 0.0035300507},
#     {'tag': [162, 167, 'Q511991'], 'score': 0.0024438812000000002},
#     {'tag': [162, 167, 'Q328304'], 'score': 0.0024438812000000002},
#     {'tag': [162, 167, 'Q111745127'], 'score': 0.0024438812000000002},
#     {'tag': [170, 176, 'Q700664'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q18105'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q1219700'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q1724455'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q17174792'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q1078637'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q1092033'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q60882343'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q2342378'], 'score': 0.0020094135},
#     {'tag': [170, 176, 'Q109576627'], 'score': 0.0020094135},
#     {'tag': [179, 188, 'Q452697'], 'score': 0.0015206372},
#     {'tag': [179, 188, 'Q95172743'], 'score': 0.0015206372},
#     {'tag': [202, 209, 'Q700385'], 'score': 0.0020818248},
#     {'tag': [202, 209, 'Q181269'], 'score': 0.0020818248},
#     {'tag': [202, 209, 'Q2390674'], 'score': 0.0011766836},
#     {'tag': [202, 209, 'Q109572628'], 'score': 0.0002715424},
#     {'tag': [202, 209, 'Q117882682'], 'score': 0.0002715424},
#     {'tag': [202, 209, 'Q2875357'], 'score': 0.0002715424}],
#    'types': {'Q618123': True},
#    'valid': None},
#   {'aliases': ['Alençon railway station',
#     'stazione di Alençon',
#     "Gare d'Alençon",
#     'Gare d’Alençon',
#     'محطة الينكون',
#     '阿朗松站',
#     "gare d'Alençon"],
#    'desc': 'gare ferroviaire française',
#    'edges': [2250897,
#     3096791,
#     142,
#     181269,
#     25989,
#     1968198,
#     123466155,
#     123497514,
#     123497516,
#     2425104,
#     3239272,
#     13646,
#     13646,
#     30740754,
#     3512113,
#     55654238],
#    'extra_aliases': None,
#    'id': 'Q2390674',
#    'label': 'Alençon',
#    'nb_sitelinks': 9,
#    'nb_statements': 32,
#    'rank': -0.5144719524,
#    'score': -0.9766731629000001,
#    'similarities': [{'tag': [0, 7, 'Q2390674'], 'score': 0.0125523013},
#     {'tag': [10, 16, 'Q142'], 'score': 0.0535774059},
#     {'tag': [10, 16, 'Q70972'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q70802'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q5478259'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q207162'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q2986910'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q168466'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q2946657'], 'score': 0.012364016700000001},
#     {'tag': [10, 16, 'Q27827753'], 'score': 0.012364016700000001},
], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q18105'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1219700'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1724455'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q17174792'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1078637'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1092033'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q60882343'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q2342378'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q109576627'], 'score': 0.0025181488000000003},
#     {'tag': [179, 188, 'Q452697'], 'score': 0.0019056261000000001},
#     {'tag': [179, 188, 'Q95172743'], 'score': 0.0019056261000000001},
#     {'tag': [202, 209, 'Q700385'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q181269'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q2390674'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q109572628'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q117882682'], 'score': 0.0026088929},
#     {'tag': [202, 209, 'Q2875357'], 'score': 0.0003402904}],
#    'types': {'Q618123': True},
#    'valid': None},
#   {'aliases': ['Alençon - Valframbert Airport',
#     'Aeroportul Alençon - Valframbert',
#     'Valframbert Airport',
#     '阿朗松-瓦爾弗朗貝爾飛行場',
#     "Aérodrome d'Alençon Valframbert",
#     'Flugplatz Alençon-Valframbert',
#     'LFOF',
#     'Alençon - Valframbert repülőtér',
#     '阿朗松-瓦尔弗朗贝尔飞行场',
#     "Aéroport d'Alençon - Valframbert",
#     'Alençon Valframbert Airport',
#     'Alencon',
#     'Alençon-Valframbert',
#     'Lapangan Terbang Valframbert'],
#    'desc': None,
#    'edges': [142],
#    'extra_aliases': None,
#    'id': 'Q2875357',
#    'label': "aérodrome d'Alençon - Valframbert",
#    'nb_sitelinks': 4,
#    'nb_statements': 18,
#    'rank': -1.738530912,
#    'score': -1.1898252816000001,
#    'similarities': [{'tag': [0, 7, 'Q2875357'], 'score': 0.0136116152},
#     {'tag': [10, 16, 'Q142'], 'score': 0.058098911100000004},
#     {'tag': [10, 16, 'Q70972'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q70802'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q5478259'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q207162'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q2986910'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q168466'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q2946657'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q27827753'], 'score': 0.013407441},
#     {'tag': [10, 16, 'Q31406071'], 'score': 0.013407441},
#     {'tag': [22, 27, 'Q12740'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q217459'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q12050959'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q26702029'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q21764720'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q32146472'], 'score': 0.0125907441},
#     {'tag': [22, 27, 'Q29788247'], 'score': 0.0125907441},
#     {'tag': [33, 48, 'Q16954'], 'score': 0.011842105300000001},
#     {'tag': [51, 58, 'Q700385'], 'score': 0.0106170599},
#     {'tag': [51, 58, 'Q181269'], 'score': 0.0106170599},
#     {'tag': [51, 58, 'Q2390674'], 'score': 0.0106170599},
#     {'tag': [51, 58, 'Q109572628'], 'score': 0.0106170599},
#     {'tag': [51, 58, 'Q117882682'], 'score': 0.0106170599},
#     {'tag': [51, 58, 'Q2875357'], 'score': 0.08139745920000001},
#     {'tag': [61, 68, 'Q700385'], 'score': 0.009936479100000001},
#     {'tag': [61, 68, 'Q181269'], 'score': 0.009936479100000001},
#     {'tag': [61, 68, 'Q2390674'], 'score': 0.009936479100000001},
#     {'tag': [61, 68, 'Q109572628'], 'score': 0.009936479100000001},
#     {'tag': [61, 68, 'Q117882682'], 'score': 0.009936479100000001},
#     {'tag': [61, 68, 'Q2875357'], 'score': 0.0761796733},
#     {'tag': [71, 77, 'Q700664'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q18105'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q1219700'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q1724455'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q17174792'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q1078637'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q1092033'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q60882343'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q2342378'], 'score': 0.0092558984},
#     {'tag': [71, 77, 'Q109576627'], 'score': 0.0092558984},
#     {'tag': [80, 86, 'Q700664'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q18105'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q1219700'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q1724455'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q17174792'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q1078637'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q1092033'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q60882343'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q2342378'], 'score': 0.0086433757},
#     {'tag': [80, 86, 'Q109576627'], 'score': 0.0086433757},
#     {'tag': [99, 106, 'Q27981014'], 'score': 0.007350272200000001},
#     {'tag': [99, 106, 'Q474498'], 'score': 0.007350272200000001},
#     {'tag': [99, 106, 'Q1724609'], 'score': 0.007350272200000001},
#     {'tag': [99, 106, 'Q202608'], 'score': 0.007350272200000001},
#     {'tag': [99, 106, 'Q3096074'], 'score': 0.007350272200000001},
#     {'tag': [99, 106, 'Q117882135'], 'score': 0.007350272200000001},
#     {'tag': [109, 117, 'Q1228266'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q1290284'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q659992'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q610051'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q3096385'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q2863778'], 'score': 0.0066696915},
#     {'tag': [109, 117, 'Q49348323'], 'score': 0.0066696915},
#     {'tag': [120, 130, 'Q729239'], 'score': 0.005921052600000001},
#     {'tag': [120, 130, 'Q1727932'], 'score': 0.005921052600000001},
#     {'tag': [133, 139, 'Q142'], 'score': 0.0218239564},
#     {'tag': [133, 139, 'Q70972'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q70802'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q5478259'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q207162'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q2986910'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q168466'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q2946657'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q27827753'], 'score': 0.0050362976000000005},
#     {'tag': [133, 139, 'Q31406071'], 'score': 0.0050362976000000005},
#     {'tag': [142, 149, 'Q700385'], 'score': 0.0044237750000000004},
#     {'tag': [142, 149, 'Q181269'], 'score': 0.0044237750000000004},
#     {'tag': [142, 149, 'Q2390674'], 'score': 0.0044237750000000004},
#     {'tag': [142, 149, 'Q109572628'], 'score': 0.0044237750000000004},
#     {'tag': [142, 149, 'Q117882682'], 'score': 0.0044237750000000004},
#     {'tag': [142, 149, 'Q2875357'], 'score': 0.033915608},
#     {'tag': [162, 167, 'Q511991'], 'score': 0.0030626134},
#     {'tag': [162, 167, 'Q328304'], 'score': 0.0030626134},
#     {'tag': [162, 167, 'Q111745127'], 'score': 0.0030626134},
#     {'tag': [170, 176, 'Q700664'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q18105'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1219700'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1724455'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q17174792'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1078637'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q1092033'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q60882343'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q2342378'], 'score': 0.0025181488000000003},
#     {'tag': [170, 176, 'Q109576627'], 'score': 0.0025181488000000003},
#     {'tag': [179, 188, 'Q452697'], 'score': 0.0019056261000000001},
#     {'tag': [179, 188, 'Q95172743'], 'score': 0.0019056261000000001},
#     {'tag': [202, 209, 'Q700385'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q181269'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q2390674'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q109572628'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q117882682'], 'score': 0.0003402904},
#     {'tag': [202, 209, 'Q2875357'], 'score': 0.0026088929}],
#    'types': {'Q618123': True},
#    'valid': None}]}

# %%
VILLESFR
# Out:
#                key                       head        head_root  SAINT  \
# 0    volume01-1065                    Afrique        [afrique]  False
# 1    volume01-1087                       AGDE           [agde]  False
# 2    volume01-1103                       AGEN           [agen]  False
# 3    volume01-1210                     AGRERE         [agrere]  False
# 4    volume01-1279                      Aigle          [aigle]  False
# ..             ...                        ...              ...    ...
# 871  volume17-2393                      WORDT          [wordt]  False
# 872  volume17-2434                    XAINTES        [xaintes]  False
# 873  volume17-2619  YRIER de la perche, saint  [yrier, perche]   True
# 874  volume17-2632                     YVETOT         [yvetot]  False
# 875  volume17-2638              YVOY, ou IVOY     [yvoy, ivoy]  False
#
#      truthyV                  truthyV_coords  \
# 0    Q818608   [43.9583333333, 2.8863888889]
# 1    Q191396           [43.31, 3.4752777778]
# 2      Q6625   [44.2030555556, 0.6186111111]
# 3    Q137514           [45.01, 4.3961111111]
# 4    Q500588    [48.765, 0.6275000000000001]
# ..       ...                             ...
# 871   Q22762   [48.9388888889, 7.7458333333]
# 872  Q191126  [45.7452777778, -0.6344444444]
# 873  Q523015   [45.5144444444, 1.2033333333]
# 874  Q691278   [49.6169444444, 0.7530555556]
# 875  Q624330         [49.6325, 5.1680555556]
#
#                                           truthyV_JSON  \
# 0    {'pageid': 771473, 'ns': 0, 'title': 'Q818608'...
# 1    {'pageid': 189694, 'ns': 0, 'title': 'Q191396'...
# 2    {'pageid': 7752, 'ns': 0, 'title': 'Q6625', 'l...
# 3    {'pageid': 139255, 'ns': 0, 'title': 'Q137514'...
# 4    {'pageid': 470872, 'ns': 0, 'title': 'Q500588'...
# ..                                                 ...
# 871  {'pageid': 26158, 'ns': 0, 'title': 'Q22762', ...
# 872  {'pageid': 189455, 'ns': 0, 'title': 'Q191126'...
# 873  {'pageid': 492059, 'ns': 0, 'title': 'Q523015'...
# 874  {'pageid': 651247, 'ns': 0, 'title': 'Q691278'...
# 875  {'pageid': 587230, 'ns': 0, 'title': 'Q624330'...
#
#                                      truthyV_spellings  truthyV_population  \
# 0    [Saint-Affrique, Vendeloves, Bournac, Saint-Ét...              7992.0
# 1                                               [Agde]             29103.0
# 2                                               [Agen]             32485.0
# 3              [Saint-Agrève, Le Pouzat, Mont-Chiniac]              2325.0
# 4                                    [L'Aigle, Laigle]              7824.0
# ..                                                 ...                 ...
# 871         [Wœrth, Woerth, Wörth, Wörth an der Sauer]              1696.0
# 872  [Saintes, Mediolanum Santonum, Xantes, Sentas,...             25518.0
# 873  [Saint-Yrieix-la-Perche, Yrieix-la-Montagne, S...              6825.0
# 874                       [Yvetot, Yvetot-la-Montagne]             11385.0
# 875  [Carignan, Yvois, Ivois, Wé, Carignan Ardennes...              2810.0
#
#                                            fullcontent  \
# 0    * Afrique , ( Géog . mod . ) petite ville de F...
# 1    * AGDE , ( Géog . ) ville de France en Langued...
# 2    * AGEN , ( Géog . ) ancienne ville de France ,...
# 3    * AGRERE ( Géog . ) petite ville de France dan...
# 4    * Aigle , ( Géog . ) petite ville de France da...
# ..                                                 ...
# 871  WORDT , ( Géog . mod . ) petite ville , ou plu...
# 872  XAINTES , ( Géog . mod . ) ville de France , c...
# 873  YRIER de la perche , saint , ( Géog . mod . ) ...
# 874  YVETOT , ( Géog . mod . ) bourg de France en N...
# 875  YVOY , ou IVOY , ( Géog . mod . ) petite ville...
#
#                                         OpenTapiocaDoc  \
# 0              AFRIQUE % France % Gascogne % Montauban
# 1         AGDE % France % Languedoc % Paris % d'Agadez
# 2    AGEN % France % l'Agénois % la Guienne % la Ga...
# 3            AGRERE % France % Monts % le haut-Vivarez
# 4    AIGLE % France % Rouen % d'Evreux % la haute N...
# ..                                                 ...
# 871  WORDT % France % Hanau % Wasgaw % la basse-Als...
# 872                    XAINTES % France % la Saintonge
# 873  SAINT YRIER DE LA PERCHE, SAINT % France % le ...
# 874  YVETOT % France % Normandie % Caux % Caudebec ...
# 875  YVOY, OU IVOY % France % Chier % Sédan % Luxem...
#
#                                     TapiocaPredictions  TapiocaDist2Truth  \
# 0    {'best_qid': 'Q15', 'best_tag_label': 'Afrique...        2566.790159
# 1    {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# 2    {'best_qid': 'Q6625', 'best_tag_label': 'Agen'...           0.000000
# 3                                                 None                NaN
# 4    {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# ..                                                 ...                ...
# 871                                               None                NaN
# 872  {'best_qid': 'Q191126', 'best_tag_label': 'Sai...           0.000000
# 873  {'best_qid': None, 'best_tag_label': None, 'en...         462.756460
# 874  {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# 875  {'best_qid': 'Q624330', 'best_tag_label': 'Car...           0.000000
#
#      TapiocaTruthInPred
# 0                 False
# 1                  True
# 2                  True
# 3                 False
# 4                  True
# ..                  ...
# 871               False
# 872                True
# 873               False
# 874                True
# 875                True
#
# [826 rows x 14 columns]

# %%
for idx, row in VILLESFR.iterrows():
    print(str(idx) + "  ######################################")
    truth = WikidataObject(uri=row['truthyV'], coordinates=row['truthyV_coords'])

    try:
        mention = row['TapiocaPredictions']

        popularity = sorted(mention['tags'],
                            key=lambda x: x['nb_statements'],
                            reverse=True)

        for rank,p in enumerate(popularity):
            try:
                pwd = WikidataObject(uri=p['id'])
                pwd.get_coordinates()
                distance = truth.distance_to(pwd)
                print('\t', p['label'], p['nb_statements'], ':', distance)

                if rank == 0:
                    VILLESFR.loc[idx, 'TapiocaBaseline'] = distance
                    

            except Exception as e:
                print(f'Error in distance calculation: {e}')

    except Exception as e:
        print(f'No Tapioca prediction: {e}')
        pass
# Out:
# 0  ######################################
# 	 Afrique 282 : 2566.79015913837
# 	 Afrique de l'Est 87 : 6043.492051392051
# 	 plaque africaine 18 : None
# 	 L'Afrique 5 : 5569.133483572722
# 1  ######################################
# 	 Agde 98 : 1.8010840583367065e-09
# 	 gare d'Agde 30 : 1.1629213791128556
# 	 canton d'Agde 19 : 6.490387809662085e-08
# 2  ######################################
# 	 Agen 131 : 4.969216059507183e-09
# 	 arrondissement d'Agen 36 : 4.930037192285652
# 	 gare d'Agen 31 : 0.6127116861752916
# 	 arrêt Agen 10 : 523.9962893779266
# 	 Agen 10 : 1957.1717201253582
# 	 Agen 6 : 1984.3044062988113
# 	 Agen (bukid) 6 : 4327.524168200131
# 	 Agen 5 : 1953.4562939356347
# 3  ######################################
# No Tapioca prediction: 'NoneType' object is not subscriptable
# 4  ######################################
# 	 L'Aigle 76 : 8.16185084879003e-15
# 	 Aigle 72 : 548.986103004263
# 	 gare d'Aigle 44 : 548.9524479800652
# 	 District d'Aigle 41 : 555.4177640595938
# 	 Edzell 30 : 921.9188646096449
# 	 L'Aigle 23 : 0.56630545386458
# 	 canton de L'Aigle-Est 18 : 4.839019884482733
# 	 canton de l'Aigle 16 : 8.16185084879003e-15
# 	 station météorologique de L'Aigle 10 : 2.6609845400544576
# 	 L'Aigle 5 : 555.2375860181605
# 5  ######################################
# 	 Allemagne 1129 : 532.6470983204407
# 	 峪山镇 47 : 8623.070721341166
# 	 aérodrome de Halliburton Field 15 : 8109.83110304968
# 	 Dục Tú 11 : 9097.444950527037
# 	 Đức Sơn 10 : 9216.132120207409
# 	 Đức La 9 : 9289.888783819584
# 	 Đức Tôn 8 : None
# 	 Quy Đức 8 : 10018.548596683771
# 	 Duć 6 : 1306.2153911319447
# 6  ######################################
# 	 Saint-Aignan 78 : 2.801093145732163e-09
# 	 Mont-Saint-Aignan 74 : 244.88973887336616
# 	 Saint-Aignan 62 : 344.54717130988905
# 	 Saint-Aignan 59 : 368.9353425724454
# 	 Saint-Aignan 58 : 289.01695939240017
# 	 Saint-Aignan 54 : 130.7418225850485
# 	 district de Wangen 16 : 154.51796827434808
# 	 arrondissement de Wangen 14 : 206.1470808901262
# 866  ######################################
# 	 Wasselonne 70 : 4.0859935819524474e-09
# 	 canton de Wasselonne 28 : 3.399758707450289
# 867  ######################################
# 	 Watten 59 : 4.895352602281082e-09
# 	 Watten 28 : 919.3647968766339
# 	 Watten 19 : 921.3883934499247
# 	 station météorologique de Watten 9 : 0.10451680793805827
# 	 Watten 6 : 6366.127323397505
# 868  ######################################
# No Tapioca prediction: 'NoneType' object is not subscriptable
# 869  ######################################
# 	 Ouest 202 : 4787.888577601601
# 	 civilisation occidentale 41 : None
# 	 conquête de l'Ouest 26 : None
# 	 West (Francfort-sur-le-Main) 15 : 185.50353784975118
# 	 Stuttgart-West 15 : 126.80515883746503
# 	 Stadtbezirk 4 West (Bremen) 13 : None
# 	 heure d'Europe de l'Ouest 9 : None
# 	 UTC+01:00 8 : None
# 	 West 8 : 648.8812350775175
# 	 Heure d'été d'Europe de l'Ouest 5 : None
# 870  ######################################
# 	 Seedorf 89 : 145.52942737338898
# 	 Sigriswil 88 : 183.56629551038168
# 	 Rüeggisberg 84 : 169.50501676534816
# 	 Därstetten 71 : 186.36710819758565
# 	 Harskirchen 55 : 68.27128401530258
# 	 Wiler 42 : 218.33239320323537
# 	 Bärschwil 37 : 107.52349280902516
# 	 Buch am Irchel 37 : 132.2958687124353
# 	 Wiler 23 : 133.81945050297603
# 	 Wiler 7 : 184.021810585442
# 871  ######################################
# No Tapioca prediction: 'NoneType' object is not subscriptable
# 872  ######################################
# 	 Saintes 118 : 4.234648651206018e-09
# 873  ######################################
# 	 Le Saint 57 : 462.75646035611743
# 	 Le Saint 7 : 462.6732301525017
# 	 Le Saint-Fût 7 : 5287.2533111778175
# 874  ######################################
# 	 Yvetot 85 : 5.85442006849729e-09
# 	 gare d'Yvetot 25 : 0.6209497077316593
# 	 canton d'Yvetot 20 : 6.212222960593034e-08
# 	 arrondissement d'Yvetot 8 : None
# 875  ######################################
# 	 Carignan 82 : 3.207493594987864e-09
# 	 Ivoy 7 : 82.82410804787685

# %%
VILLESFR[VILLESFR['TapiocaBaseline'] < 20].shape[0]/VILLESFR.shape[0]
# Out:
# 0.5883777239709443

# %%
VILLESFR[VILLESFR['TapiocaDist2Truth'] < 50].merge(VILLESFR[VILLESFR['TapiocaBaseline'] < 20],
                                                  on='key')
# Out:
#                key         head_x      head_root_x  SAINT_x truthyV_x  \
# 0    volume01-1087           AGDE           [agde]    False   Q191396
# 1    volume01-1103           AGEN           [agen]    False     Q6625
# 2    volume01-1279          Aigle          [aigle]    False   Q500588
# 3    volume01-1312  AIGUES-MORTES  [aigues-mortes]    False   Q193809
# 4    volume01-1369      AIGURANDE      [aigurande]    False   Q211643
# ..             ...            ...              ...      ...       ...
# 456  volume17-2104     WASSELONNE     [wasselonne]    False    Q22413
# 457  volume17-2116         WATTEN         [watten]    False   Q742424
# 458  volume17-2434        XAINTES        [xaintes]    False   Q191126
# 459  volume17-2632         YVETOT         [yvetot]    False   Q691278
# 460  volume17-2638  YVOY, ou IVOY     [yvoy, ivoy]    False   Q624330
#
#                    truthyV_coords_x  \
# 0             [43.31, 3.4752777778]
# 1     [44.2030555556, 0.6186111111]
# 2      [48.765, 0.6275000000000001]
# 3           [43.5666666667, 4.1925]
# 4     [46.4341666667, 1.8288888889]
# ..                              ...
# 456   [48.6372222222, 7.4480555556]
# 457         [50.8330555556, 2.2125]
# 458  [45.7452777778, -0.6344444444]
# 459   [49.6169444444, 0.7530555556]
# 460         [49.6325, 5.1680555556]
#
#                                         truthyV_JSON_x  \
# 0    {'pageid': 189694, 'ns': 0, 'title': 'Q191396'...
# 1    {'pageid': 7752, 'ns': 0, 'title': 'Q6625', 'l...
# 2    {'pageid': 470872, 'ns': 0, 'title': 'Q500588'...
# 3    {'pageid': 191785, 'ns': 0, 'title': 'Q193809'...
# 4    {'pageid': 207300, 'ns': 0, 'title': 'Q211643'...
# ..                                                 ...
# 456  {'pageid': 25764, 'ns': 0, 'title': 'Q22413', ...
# 457  {'pageid': 698388, 'ns': 0, 'title': 'Q742424'...
# 458  {'pageid': 189455, 'ns': 0, 'title': 'Q191126'...
# 459  {'pageid': 651247, 'ns': 0, 'title': 'Q691278'...
# 460  {'pageid': 587230, 'ns': 0, 'title': 'Q624330'...
#
#                                    truthyV_spellings_x  truthyV_population_x  \
# 0                                               [Agde]               29103.0
# 1                                               [Agen]               32485.0
# 2                                    [L'Aigle, Laigle]                7824.0
# 3         [Aigues-Mortes, Aigues Morte, Fort-Peletier]                8685.0
# 4                                          [Aigurande]                1359.0
# ..                                                 ...                   ...
# 456                          [Wasselonne, Wasselnheim]                5774.0
# 457                             [Watten, Waten, Woatn]                2577.0
# 458  [Saintes, Mediolanum Santonum, Xantes, Sentas,...               25518.0
# 459                       [Yvetot, Yvetot-la-Montagne]               11385.0
# 460  [Carignan, Yvois, Ivois, Wé, Carignan Ardennes...                2810.0
#
#                                          fullcontent_x  ...  \
# 0    * AGDE , ( Géog . ) ville de France en Langued...  ...
# 1    * AGEN , ( Géog . ) ancienne ville de France ,...  ...
# 2    * Aigle , ( Géog . ) petite ville de France da...  ...
# 3    * AIGUES-MORTES , ( Géog . ) ville de France ,...  ...
# 4    AIGURANDE , ( Géog . ) ville de France dans la...  ...
# ..                                                 ...  ...
# 456  WASSELONNE , ( Géog . mod . ) bourg ou petite ...  ...
# 457  WATTEN , ( Géog . mod . ) petite ville de Fran...  ...
# 458  XAINTES , ( Géog . mod . ) ville de France , c...  ...
# 459  YVETOT , ( Géog . mod . ) bourg de France en N...  ...
# 460  YVOY , ou IVOY , ( Géog . mod . ) petite ville...  ...
#
#                    truthyV_coords_y  \
# 0             [43.31, 3.4752777778]
# 1     [44.2030555556, 0.6186111111]
# 2      [48.765, 0.6275000000000001]
# 3           [43.5666666667, 4.1925]
# 4     [46.4341666667, 1.8288888889]
# ..                              ...
# 456   [48.6372222222, 7.4480555556]
# 457         [50.8330555556, 2.2125]
# 458  [45.7452777778, -0.6344444444]
# 459   [49.6169444444, 0.7530555556]
# 460         [49.6325, 5.1680555556]
#
#                                         truthyV_JSON_y  \
# 0    {'pageid': 189694, 'ns': 0, 'title': 'Q191396'...
# 1    {'pageid': 7752, 'ns': 0, 'title': 'Q6625', 'l...
# 2    {'pageid': 470872, 'ns': 0, 'title': 'Q500588'...
# 3    {'pageid': 191785, 'ns': 0, 'title': 'Q193809'...
# 4    {'pageid': 207300, 'ns': 0, 'title': 'Q211643'...
# ..                                                 ...
# 456  {'pageid': 25764, 'ns': 0, 'title': 'Q22413', ...
# 457  {'pageid': 698388, 'ns': 0, 'title': 'Q742424'...
# 458  {'pageid': 189455, 'ns': 0, 'title': 'Q191126'...
# 459  {'pageid': 651247, 'ns': 0, 'title': 'Q691278'...
# 460  {'pageid': 587230, 'ns': 0, 'title': 'Q624330'...
#
#                                    truthyV_spellings_y  truthyV_population_y  \
# 0                                               [Agde]               29103.0
# 1                                               [Agen]               32485.0
# 2                                    [L'Aigle, Laigle]                7824.0
# 3         [Aigues-Mortes, Aigues Morte, Fort-Peletier]                8685.0
# 4                                          [Aigurande]                1359.0
# ..                                                 ...                   ...
# 456                          [Wasselonne, Wasselnheim]                5774.0
# 457                             [Watten, Waten, Woatn]                2577.0
# 458  [Saintes, Mediolanum Santonum, Xantes, Sentas,...               25518.0
# 459                       [Yvetot, Yvetot-la-Montagne]               11385.0
# 460  [Carignan, Yvois, Ivois, Wé, Carignan Ardennes...                2810.0
#
#                                          fullcontent_y  \
# 0    * AGDE , ( Géog . ) ville de France en Langued...
# 1    * AGEN , ( Géog . ) ancienne ville de France ,...
# 2    * Aigle , ( Géog . ) petite ville de France da...
# 3    * AIGUES-MORTES , ( Géog . ) ville de France ,...
# 4    AIGURANDE , ( Géog . ) ville de France dans la...
# ..                                                 ...
# 456  WASSELONNE , ( Géog . mod . ) bourg ou petite ...
# 457  WATTEN , ( Géog . mod . ) petite ville de Fran...
# 458  XAINTES , ( Géog . mod . ) ville de France , c...
# 459  YVETOT , ( Géog . mod . ) bourg de France en N...
# 460  YVOY , ou IVOY , ( Géog . mod . ) petite ville...
#
#                                       OpenTapiocaDoc_y  \
# 0         AGDE % France % Languedoc % Paris % d'Agadez
# 1    AGEN % France % l'Agénois % la Guienne % la Ga...
# 2    AIGLE % France % Rouen % d'Evreux % la haute N...
# 3            AIGUES-MORTES % France % le bas Languedoc
# 4               AIGURANDE % France % Berry % la Marche
# ..                                                 ...
# 456        WASSELONNE % France % Alsace % Wasselenheim
# 457    WATTEN % France % Bourbourg % la Flandre % l'An
# 458                    XAINTES % France % la Saintonge
# 459  YVETOT % France % Normandie % Caux % Caudebec ...
# 460  YVOY, OU IVOY % France % Chier % Sédan % Luxem...
#
#                                   TapiocaPredictions_y  TapiocaDist2Truth_y  \
# 0    {'best_qid': None, 'best_tag_label': None, 'en...                  0.0
# 1    {'best_qid': 'Q6625', 'best_tag_label': 'Agen'...                  0.0
# 2    {'best_qid': None, 'best_tag_label': None, 'en...                  0.0
# 3    {'best_qid': None, 'best_tag_label': None, 'en...                  0.0
# 4    {'best_qid': None, 'best_tag_label': None, 'en...                  0.0
# ..                                                 ...                  ...
# 456  {'best_qid': 'Q22413', 'best_tag_label': 'Wass...                  0.0
# 457  {'best_qid': 'Q742424', 'best_tag_label': 'Wat...                  0.0
# 458  {'best_qid': 'Q191126', 'best_tag_label': 'Sai...                  0.0
# 459  {'best_qid': None, 'best_tag_label': None, 'en...                  0.0
# 460  {'best_qid': 'Q624330', 'best_tag_label': 'Car...                  0.0
#
#     TapiocaTruthInPred_y TapiocaBaseline_y
# 0                   True      1.801084e-09
# 1                   True      4.969216e-09
# 2                   True      8.161851e-15
# 3                   True      3.667221e-09
# 4                   True      3.766769e-09
# ..                   ...               ...
# 456                 True      4.085994e-09
# 457                 True      4.895353e-09
# 458                 True      4.234649e-09
# 459                 True      5.854420e-09
# 460                 True      3.207494e-09
#
# [461 rows x 29 columns]

# %%
VILLESFR[VILLESFR['TapiocaDist2Truth'] < 50].loc[:10]
# Out:
#              key           head        head_root  SAINT  truthyV  \
# 1  volume01-1087           AGDE           [agde]  False  Q191396
# 2  volume01-1103           AGEN           [agen]  False    Q6625
# 4  volume01-1279          Aigle          [aigle]  False  Q500588
# 8  volume01-1312  AIGUES-MORTES  [aigues-mortes]  False  Q193809
#
#                   truthyV_coords  \
# 1          [43.31, 3.4752777778]
# 2  [44.2030555556, 0.6186111111]
# 4   [48.765, 0.6275000000000001]
# 8        [43.5666666667, 4.1925]
#
#                                         truthyV_JSON  \
# 1  {'pageid': 189694, 'ns': 0, 'title': 'Q191396'...
# 2  {'pageid': 7752, 'ns': 0, 'title': 'Q6625', 'l...
# 4  {'pageid': 470872, 'ns': 0, 'title': 'Q500588'...
# 8  {'pageid': 191785, 'ns': 0, 'title': 'Q193809'...
#
#                               truthyV_spellings  truthyV_population  \
# 1                                        [Agde]             29103.0
# 2                                        [Agen]             32485.0
# 4                             [L'Aigle, Laigle]              7824.0
# 8  [Aigues-Mortes, Aigues Morte, Fort-Peletier]              8685.0
#
#                                          fullcontent  \
# 1  * AGDE , ( Géog . ) ville de France en Langued...
# 2  * AGEN , ( Géog . ) ancienne ville de France ,...
# 4  * Aigle , ( Géog . ) petite ville de France da...
# 8  * AIGUES-MORTES , ( Géog . ) ville de France ,...
#
#                                       OpenTapiocaDoc  \
# 1       AGDE % France % Languedoc % Paris % d'Agadez
# 2  AGEN % France % l'Agénois % la Guienne % la Ga...
# 4  AIGLE % France % Rouen % d'Evreux % la haute N...
# 8          AIGUES-MORTES % France % le bas Languedoc
#
#                                   TapiocaPredictions  TapiocaDist2Truth  \
# 1  {'best_qid': None, 'best_tag_label': None, 'en...                0.0
# 2  {'best_qid': 'Q6625', 'best_tag_label': 'Agen'...                0.0
# 4  {'best_qid': None, 'best_tag_label': None, 'en...                0.0
# 8  {'best_qid': None, 'best_tag_label': None, 'en...                0.0
#
#    TapiocaTruthInPred  TapiocaBaseline
# 1                True     1.801084e-09
# 2                True     4.969216e-09
# 4                True     8.161851e-15
# 8                True     3.667221e-09

# %%
VILLESFR[VILLESFR['TapiocaBaseline'] < 20].loc[:10]
# Out:
#               key              head           head_root  SAINT   truthyV  \
# 1   volume01-1087              AGDE              [agde]  False   Q191396
# 2   volume01-1103              AGEN              [agen]  False     Q6625
# 4   volume01-1279             Aigle             [aigle]  False   Q500588
# 6   volume01-1286    AIGNAN (Saint)            [aignan]   True   Q832394
# 7   volume01-1292  AIGREMONT-LE-DUC  [aigremont-le-duc]  False  Q1102347
# 8   volume01-1312     AIGUES-MORTES     [aigues-mortes]  False   Q193809
# 10  volume01-1365         Aiguillon         [aiguillon]  False   Q404783
#
#                          truthyV_coords  \
# 1                 [43.31, 3.4752777778]
# 2         [44.2030555556, 0.6186111111]
# 4          [48.765, 0.6275000000000001]
# 6   [47.2686111111, 1.3758333333000001]
# 7         [48.0169444444, 5.7172222222]
# 8               [43.5666666667, 4.1925]
# 10              [44.3005555556, 0.3375]
#
#                                          truthyV_JSON  \
# 1   {'pageid': 189694, 'ns': 0, 'title': 'Q191396'...
# 2   {'pageid': 7752, 'ns': 0, 'title': 'Q6625', 'l...
# 4   {'pageid': 470872, 'ns': 0, 'title': 'Q500588'...
# 6   {'pageid': 785092, 'ns': 0, 'title': 'Q832394'...
# 7   {'pageid': 1049688, 'ns': 0, 'title': 'Q110234...
# 8   {'pageid': 191785, 'ns': 0, 'title': 'Q193809'...
# 10  {'pageid': 383812, 'ns': 0, 'title': 'Q404783'...
#
#                                     truthyV_spellings  truthyV_population  \
# 1                                              [Agde]             29103.0
# 2                                              [Agen]             32485.0
# 4                                   [L'Aigle, Laigle]              7824.0
# 6   [Saint-Aignan, Saint-Aignan-sur-Cher, Saint-Ai...              2821.0
# 7                                         [Aigremont]                26.0
# 8        [Aigues-Mortes, Aigues Morte, Fort-Peletier]              8685.0
# 10                                [Aiguillon, Gulhon]              4118.0
#
#                                           fullcontent  \
# 1   * AGDE , ( Géog . ) ville de France en Langued...
# 2   * AGEN , ( Géog . ) ancienne ville de France ,...
# 4   * Aigle , ( Géog . ) petite ville de France da...
# 6   AIGNAN ( Saint ) ( Géog . ) ville de France da...
# 7   * AIGREMONT-LE-DUC , ( Géogr . ) Ville de Fran...
# 8   * AIGUES-MORTES , ( Géog . ) ville de France ,...
# 10  Aiguillon , ( Géog . ) ville de France en Guye...
#
#                                        OpenTapiocaDoc  \
# 1        AGDE % France % Languedoc % Paris % d'Agadez
# 2   AGEN % France % l'Agénois % la Guienne % la Ga...
# 4   AIGLE % France % Rouen % d'Evreux % la haute N...
# 6   SAINT AIGNAN (SAINT) % France % le Berry % le ...
# 7       AIGREMONT-LE-DUC % France % Bourgogne % Dijon
# 8           AIGUES-MORTES % France % le bas Languedoc
# 10           AIGUILLON % France % Guyenne % l'Agenois
#
#                                    TapiocaPredictions  TapiocaDist2Truth  \
# 1   {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# 2   {'best_qid': 'Q6625', 'best_tag_label': 'Agen'...           0.000000
# 4   {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# 6   {'best_qid': 'Q1055925', 'best_tag_label': 'Mo...         244.889739
# 7   {'best_qid': None, 'best_tag_label': None, 'en...         290.667320
# 8   {'best_qid': None, 'best_tag_label': None, 'en...           0.000000
# 10  {'best_qid': None, 'best_tag_label': None, 'en...         198.880044
#
#     TapiocaTruthInPred  TapiocaBaseline
# 1                 True     1.801084e-09
# 2                 True     4.969216e-09
# 4                 True     8.161851e-15
# 6                 True     2.801093e-09
# 7                 True     5.165144e-09
# 8                 True     3.667221e-09
# 10                True     4.889955e-09

# %%
# amount of distances below 20 kms in colums 'TapiocaBaseline', and not NaN
print(VILLESFR[VILLESFR['TapiocaBaseline'] < 20].shape[0])
print(VILLESFR[VILLESFR['TapiocaBaseline'] >= 20].shape[0])
print(VILLESFR[VILLESFR['TapiocaBaseline'].notna()].shape[0])
# Out:
# 486
# 205
# 691

# %%
VILLESFR.to_json('/home/antoine/Documents/GitHub/toponym-disambiguation/data/VILLESFR_050324_frenchtapiocapreds.json')

# %%
VILLESFR['TapiocaPredictions'].apply(lambda preds: len(preds['tags']) if preds else 0).describe()
# Out:
# count    826.000000
# mean       4.351090
# std        3.411244
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        7.000000
# max       10.000000
# Name: TapiocaPredictions, dtype: float64

# %%
verbose = False
for idx, row in VILLESFR.iterrows():

    if verbose:
        print(str(idx) + "  ######################################")

    #truth = WikidataObject(uri=row['truthyV'], coordinates=row['truthyV_coords'])

    mention = row['TapiocaPredictions']
    if mention:
        popularity_ranking = sorted(mention['tags'],
                                    key=lambda x: x['nb_statements'],
                                    reverse=True)
        baseline = popularity_ranking[0]['id']

        score_ranking = sorted(mention['tags'],
                            key=lambda x: x['score'],
                            reverse=True)

        #position of baseline in score_ranking
        for i, tag in enumerate(score_ranking):
            if tag['id'] == baseline:
                VILLESFR.at[idx, 'baseline_position'] = i
                if verbose:
                    print(i)
                break

    else:
        if verbose:
            print('no mention')

# %%
VILLESFR['baseline_position'].describe()
VILLESFR['baseline_position'].value_counts(normalize=True)
# Out:
# baseline_position
# 0.0    0.755714
# 1.0    0.165714
# 2.0    0.035714
# 4.0    0.014286
# 3.0    0.014286
# 6.0    0.005714
# 7.0    0.002857
# 8.0    0.002857
# 5.0    0.001429
# 9.0    0.001429
# Name: proportion, dtype: float64

# %% [markdown]
# # Back to Lesk method

# %%
import pandas as pd
import json
import os
from tqdm import tqdm
import requests
import seaborn as sns
import pysolr 
from unidecode import unidecode

# %%
def get_linked_resources_count(qid):

# %%
def uri2json(uri, json_cache = {}):
    """
    for a given URI of a Wikidata Ressource (WR),
    and a dict of already know URI-JSON pairs json_cache={'uri': JSON},
    enrich the json_cache and
    returns
    - the uri
    - the updated json_cache
    - data : the JSON of the WR
    """
    #data to return :
    #data = None
    
    # Check if the label is already in the cache
    if uri in json_cache:
        data = json_cache[uri]
    
    else : 
        try :
            url = f'https://www.wikidata.org/wiki/Special:EntityData/{uri}.json'
            response = requests.get(url)
            data = response.json()
            # Store the json in the cache
            json_cache[uri] = data
        except :
            print('Error requesting json at url ', url)
            json_cache[uri] = 'ERROR_REQUEST'
            pass
             
    return uri, json_cache, data

def json2labels(uri, data):
    """
    for Wikidata Ressource (WR) JSON,
    reads thze JSON and returns ;
    - uri
    - the french and 
    - english labels of the WR
    """
    
    LABEL_fr = 'NO_ENTITIES'
    LABEL_en = 'NO_ENTITIES'
    # Check if the label is already in the cache
    try : 
        entity = data.get('entities', {}).get(uri)
        labels = entity.get('labels', {})
        LABEL_fr = labels.get('fr', {}).get('value')
        LABEL_en = labels.get('en', {}).get('value')
    except :
        print('while reading the JSON, no entities found at uri ', uri)
        pass
    
    return LABEL_fr, LABEL_en

def uri2values(URI, json_cache = {}):
    """
    for a given URI of a Wikidata Ressource (WR),
    and a json_cache dict {'uri': JSON} of already know vocabulary,
    reads the corresponding JSON and returns
    - uri
    - the updated json_cache (with p31- and p131-neighbors' labels)
    - label_fr, label_en,
    - description_fr, description_en,
    - p31_uris : the list of URIS to which the WR is connected to by a P31 property,
    - p31_labels : the list of 2-tuples labels (label_fr, label_en) 
    to which the WR is connected to by a P31 property,
    - similarily, p131_uris, p131_labels
    """
    # uri same as URI, JSON_CACHE is the updated json_cache, data is the JSON datas
    uri, JSON_CACHE, data = uri2json(URI, json_cache)
    # labels or 'NO_ENTITES'
    label_fr, label_en = json2labels(URI, data)
    
    #initialisation data
    description_fr = description_en = 'NO_DESC'
    p31_uris = 'NO_P31_URIS'
    p31_labels = 'NO_P31_LAB'
    p131_uris = 'NO_P131_URIS'
    p131_labels = 'NO_P131_LAB'
    p361_uris = 'NO_P361_URIS'
    p361_labels = 'NO_P361_LAB'
    
    try :
        entity = data.get('entities', {}).get(URI)
        descriptions = entity.get('descriptions', {})
        description_fr = descriptions.get('fr', {}).get('value')
        description_en = descriptions.get('en', {}).get('value')
    except :
        print('no descriptions at URI ', uri)
        pass
    
    try : 
        properties = entity.get('claims', {})
        p31_values = properties.get('P31', [])
        p31_uris = [claim['mainsnak']['datavalue']['value']['id'] for claim in p31_values if 'datavalue' in claim['mainsnak']]
        p31_labels = []
        for uri31 in p31_uris :
            uri31, JSON_CACHE, datap31 = uri2json(uri31, JSON_CACHE)
            p31_labels.append(json2labels(uri31, datap31))
    except :
        print('no p31 at URI ', uri)
        pass
    
    try :
        p131_values = properties.get('P131', [])
        p131_uris = [claim['mainsnak']['datavalue']['value']['id'] for claim in p131_values if 'datavalue' in claim['mainsnak']]
        p131_labels = []
        for uri131 in p131_uris :
            uri131, JSON_CACHE, datap131 = uri2json(uri131, JSON_CACHE)
            p131_labels.append(json2labels(uri131, datap131))
    except :
        print('no p131 at URI ', uri)
        pass
    
    try :
        p361_values = properties.get('P361', [])
        p361_uris = [claim['mainsnak']['datavalue']['value']['id'] for claim in p361_values if 'datavalue' in claim['mainsnak']]
        p361_labels = []
        for uri361 in p361_uris :
            uri361, JSON_CACHE, datap361 = uri2json(uri361, JSON_CACHE)
            p361_labels.append(json2labels(uri361, datap361))
    except :
        print('no p361 at URI ', uri)
        pass   

    return URI, JSON_CACHE, label_fr, label_en, description_fr, description_en, p31_uris, p31_labels, p131_uris, p131_labels, p361_uris, p361_labels

def process_uri(uri, cache):
    uri, JSON_CACHE, label_fr, label_en, description_fr, description_en, p31_uris, p31_labels, p131_uris, p131_labels, p361_uris, p361_labels = uri2values(uri, cache)
    return JSON_CACHE, {
        'uri': uri,
        'label_fr': label_fr,
        'label_en': label_en,
        'desc_fr': description_fr,
        'desc_en': description_en,
        'p31_uris': p31_uris,
        'p31_labels': p31_labels,
        'p131_uris': p131_uris,
        'p131_labels': p131_labels,
        'p361_uris': p361_uris,
        'p361_labels': p361_labels,
    }

def RETRIEVE_TOPONYM_ECOSYSTEM(URI, properties='', json_cache={}):
    """
    For a given URI of a Wikidata Resource (WR),
    and a json_cache dict {'uri': JSON} of already known vocabulary,
    reads the corresponding JSON and returns
    - uri
    - the updated json_cache (with p31- and p131-neighbors' labels)
    - label_fr, label_en,
    - description_fr, description_en,
    - properties_data: dict where values are such as :
        {'P31': (['Q484170'],
                 [('commune française', 'commune of France')]  --> the list of 2-tuples labels (label_fr, label_en)
                 ),
         'P131': (['Q12779', 'Q700845'],
                  [('Tarn-et-Garonne', 'Tarn-et-Garonne'), ('arrondissement de Castelsarrasin', 'arrondissement of Castelsarrasin')]
                  )
        }
    """

    # uri same as URI, JSON_CACHE is the updated json_cache, data is the JSON data
    uri, JSON_CACHE, data = uri2json(URI, json_cache)
    # labels or 'NO_ENTITIES'
    label_fr, label_en = json2labels(URI, data)

    # initialization data
    description_fr = 'NO_DESC'
    description_en = 'NO_DESC'
    properties_uris = 'NO_PROPERTIES_URIS'
    properties_labels = 'NO_PROPERTIES_LABELS'

    try:
        entity = data.get('entities', {}).get(URI)
        descriptions = entity.get('descriptions', {})
        description_fr = descriptions.get('fr', {}).get('value')
        description_en = descriptions.get('en', {}).get('value')
    except:
        print('no descriptions at URI ', uri)
        pass

    try:
        properties_data = {}
        for property_code in properties.split(','):
            property_values = entity.get('claims', {}).get(property_code, [])
            property_uris = [claim['mainsnak']['datavalue']['value']['id'] for claim in property_values
                             if 'datavalue' in claim['mainsnak']]
            property_labels = []
            for property_uri in property_uris:
                property_uri, JSON_CACHE, property_data = uri2json(property_uri, JSON_CACHE)
                property_labels.append(json2labels(property_uri, property_data))
            properties_data[property_code] = (property_uris, property_labels)
    except:
        print(f'Error processing properties at URI {uri}')
        pass

    return URI, JSON_CACHE, label_fr, label_en, description_fr, description_en, properties_data

# %%
def phrase2candidates(motforme, collection = 'frenchtapioca4', query = '', parameters = '', ):
    """ from
    - a phrase string in text
    - a given collection indexed with Solr
    - a query (default=  label:phrase~)
    - query parameters (delfaut= {"indent":"true", "fl":"uri,label", "rows":"10", "q.op":"OR", "useParams":""})
    - rows = the max number of suggestions 
    returns the top 10(default beamsearch) from Lucene indexation
    at format solr.response
    """
    #Solr instance 
    url_collec = 'http://localhost:8983/solr/' + collection +'/'
    try :
        solr = pysolr.Solr(url_collec, always_commit=True,)
        #print ('Connected to ', url_collec)
    except :
        print('Error connecting to ', url_collec)
        return None
    
    
    #query building
    if query == '' :
        pattern = 'name_tag:{}~'.format(motforme)
        args = { "indent":"true", "fl":"id,label", "q.op":"OR", "useParams":""}
    else :
        pattern = query 
        args = parameters
    
    response = solr.search(pattern, ** args)
    
    return response

# %%
import pandas as pd
from pyymatcher import PyyMatcher
import difflib
import Levenshtein
import textdistance as td
import metaphone
import pylcs
import jellyfish

def JW(a, b):
    return jellyfish.jaro_winkler_similarity(a,b)

def gpm(a, b):
    a = a.lower()
    b = b.lower()
    obj = PyyMatcher(a, b)
    return obj.ratio()

def inter(s1, s2):
    s = difflib.SequenceMatcher(None, s1.lower(), s2.lower())
    pos_a, pos_b, size = s.find_longest_match(0, len(s1), 0, len(s2))
    return size 

def overlap(s1, s2):
    s = difflib.SequenceMatcher(None, s1.lower(), s2.lower())
    pos_a, pos_b, size = s.find_longest_match(0, len(s1), 0, len(s2))
    return size / min(len(s1), len(s2))

def levenshtein(a, b):
    return Levenshtein.distance(a, b, )

def cosinus(a, b):
    return td.cosine(a,b)

def lcsseq(a ,b):
    return pylcs.lcs_sequence_length(a,b)/ min(len(a), len(b))

def ratio_double_metaphone(a,b, method = lcsseq):
    dma = metaphone.doublemetaphone(a)[0]
    dmb = metaphone.doublemetaphone(b)[0]
    return method(dma,dmb)

# Function to calculate metrics based on GPM distance
def COMPUTE_OVERLAP(V, Ci, 
                    method1 = ratio_double_metaphone, alpha1=0.9, 
                    method2 = lcsseq, alpha2 = 0.8,
                    method3 = overlap, alpha3 = 0.5):
    """ returns the number of items matchings, following the methods and thresholds given 
    """
    #for each word in V, counts if a match is found among C 
    intersection = 0 
    approx_matches = []
    for v_label in V:    
        for ci_label in Ci:
            #if we find string_method > alpha, we consider it's close enough
            if (method1(unidecode(v_label), unidecode(ci_label)) > alpha1) and (method2(unidecode(v_label),unidecode(ci_label)) > alpha2) and (method3(unidecode(v_label),unidecode(ci_label)) > alpha3):
                intersection += 1
                approx_matches.append((v_label, ci_label))
                break

    
    return intersection, approx_matches

# %%
def SIMPLE_LESK(Head,
                SetContext,
                sainteté = False,
                prop = 'P17,P31,P131,P361,P206,P47',
                imprimer = False,
                quantité = 20,
                
               ):
    """
    From the head and context set of toponyms, and the properties judged relevant,
    returns
    1) the Solr document of candidates
    2) Best Candidate URI
    3) a dict of results like {BestCandidate: {'label': 'Rambert', 'overlap': .25, 'inlink':100}}
    
    Input : 
    -Head: single string or list of alias
    -SetContext: list of strings
    -sainteté: True if 'Saint' should be part of the query
    
    (default properties retrieved are :
        wd:P17	country
        wd:P31	instance of
        wd:P47	shares border with
        wd:P361	part of
        wd:P206	located in or next to body of water
        wd:P131	located in the administrative territorial entity
    )    
    
    
    the query is as such :
    {
      "responseHeader":{
        "zkConnected":true,
        "status":0,
        "QTime":13,
        "params":{
          "q":"(label:rambert^2 OR (label:rambert~1)^1) AND label:saint",
          "indent":"true",
          "fl":"uri label score",
          "q.op":"OR",
          "sort":"score desc",
          "useParams":""
        }
    },
    
    NEW QUERY
    (label:rambert^2 OR label:rambert~0.7)^1 AND label:saint

    """
    
    #Build Query
    Qi = ""
    for k in range(len(Head)) :
        Qi += '(label:{}^2 OR (label:{}~1)^1)'.format(Head[k], Head[k])
        if k != len(Head) - 1 :
            Qi += ' OR '
    if sainteté == True :
        Qi += " AND name_tag:*saint*"
    Pi = {"indent":"true",
          "fl":"id, label, score",
          "rows": str(quantité),
          "q.op":"OR",
          "useParams":""}
    INDEX = 'testvillesfr'
    if imprimer :
        print('Query : ',Qi)
        print('Parameters :')
        print(Pi, '\n')
    
    #Retrieve candidates
    SetofCandidates = phrase2candidates(motforme=Head, collection= INDEX, query=Qi, parameters = Pi)    
    
    #initialization
    BestCandidate = 'Q0'
    maxoverlap = 0
    maxinlink = 0
    CandidatesPerformances = {BestCandidate: {'label': 'None',
                              'inlink': 0 ,                             
                              'ecosystem': [],
                              'overlap': maxoverlap,
                              'matchs': [],}
             }
    for i,candidate in enumerate(SetofCandidates.docs) :
        qid = candidate['uri'][0]
        inlink = get_linked_resources_count(qid)
        CandidatesPerformances[qid] = {'label': candidate['label'][0]}
        CandidatesPerformances[qid]['inlink'] = inlink
        if inlink > maxinlink :
            BestCandidate = qid
            maxinlink = inlink
    
    # MAIN ITERATION
    for i,candidate in enumerate(SetofCandidates.docs) :
        qid = candidate['uri'][0]
        
        #Building the Ecosystem
        Ecosystem_i = []
       
        URI, _, _,_,_,_, properties_data = RETRIEVE_TOPONYM_ECOSYSTEM(qid, properties=prop)
        
        for key,value in properties_data.items():
            labels = value[1]
            for k in range(len(labels)) : 
                prefered_label = labels[k][0] if labels[k][0] is not None else labels[k][1]
                Ecosystem_i.append(prefered_label.lower())
        
        #compute the overlap
        CandidatesPerformances[qid]['ecosystem'] = Ecosystem_i
        overlap,matchs  = COMPUTE_OVERLAP(SetContext, Ecosystem_i,)
        
        # AMPUTATION TOPONYMIQUE ?
        #amputation_overlap, amputation_matchs = COMPUTE_OVERLAP(Head, Ecosystem_i)
        #overlap += amputation_overlap
        # ADJONCTION TOPONYMIQUE ? 
        #adjonction_overlap, adjonction_matchs = COMPUTE_OVERLAP(SetContext, INLINK[qid]['label'])
        #overlap += adjonction_overlap
        
        CandidatesPerformances[qid]['overlap'] = overlap
        CandidatesPerformances[qid]['matchs'] = matchs      
        if imprimer :
            print("building '''{}''' {}'s ecosystem (inlinks : {}) : ".format(candidate['label'][0], qid, CandidatesPerformances[qid]['inlink']))
            print('Overlap of {} with {}'.format(overlap, Ecosystem_i))
            print(matchs)
        
        if (overlap > maxoverlap) :
            if imprimer :
                print('\033[97;40m' + '######################################################OJO \n' + '\033[0m')
            maxoverlap = overlap
            BestCandidate = qid
            
        if (overlap == maxoverlap) and (CandidatesPerformances[qid]['inlink'] > CandidatesPerformances[BestCandidate]['inlink']) :
            if imprimer :
                print('\033[97;40m' + '######################################################OJO \n' + '\033[0m')
            maxoverlap = overlap
            BestCandidate = qid
    
    
    if imprimer :
        print('------------------')
        print('------------------')
        print('------------------')
        print(maxoverlap, 'with', BestCandidate,)
        print('------------------')
        print('------------------')
        print('------------------')
    return SetofCandidates, BestCandidate, CandidatesPerformances
